# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #1D CNN(Predict_LOG)

# %%
import os
import time
import numpy as np
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score

csv_file = "/content/drive/MyDrive/HAR Data & Models/sb_IMU.csv"
model_path = "/content/drive/MyDrive/HAR Data & Models/wisdm_final_1dcnn_model.h5"
output_log = "1D_CNN.csv"

window_size = 60
stride = 60
sampling_rate = 30
features = ['Acc_X', 'Acc_Y', 'Acc_Z', 'Gyro_X', 'Gyro_Y', 'Gyro_Z']
label_column = "Label"

categories = [1, 2, 3, 4, 5]

def decode_activity(label):
    mapping = {
        1: "Walking",
        2: "Jogging",
        3: "Sitting",
        4: "Standing",
        5: "Stair "
    }
    return mapping.get(label, "Unknown")


def normalize_segment(segment_array):
    scaler = StandardScaler()
    normalized = scaler.fit_transform(segment_array)  # shape (60, 6)
    return normalized


if not os.path.exists(output_log):
    with open(output_log, "w") as f:
        f.write("Timestamp,Actual_Label,Predicted_Label,Latency(ms),Valid\n")


model = load_model(model_path)

def live_predict():
    print("📡 Monitoring for new data in sliding windows...\nPress Ctrl+C to stop.\n")
    last_row_read = 0

    all_actual = []
    all_predicted = []

    try:
        while True:
            if not os.path.exists(csv_file):
                print(f"Waiting for file {csv_file} to appear...")
                time.sleep(1)
                continue

            df = pd.read_csv(csv_file,low_memory=False)

            if not all(col in df.columns for col in features + [label_column]):
                print("Missing required columns. Waiting...")
                time.sleep(1)
                continue

            total_rows = len(df)

            if total_rows >= window_size:
                while last_row_read + window_size <= total_rows:
                    window = df.iloc[last_row_read:last_row_read + window_size]
                    actual_labels = window[label_column].values

                    if np.all(actual_labels == 0):
                        print(f"🪟 Rows {last_row_read+1}-{last_row_read+window_size} → Skipped (Label 0)")
                        last_row_read += stride
                        continue

                    feature_chunk = window[features].values
                    norm_chunk = normalize_segment(feature_chunk)
                    X_input = norm_chunk[np.newaxis, ...]

                    start_time = time.time()
                    prediction = model.predict(X_input, verbose=0)[0]
                    latency_ms = round((time.time() - start_time) * 1000, 2)

                    predicted_label = categories[np.argmax(prediction)]
                    decoded_pred = decode_activity(predicted_label)

                    actual_labels = actual_labels[actual_labels != 0]
                    actual_label = np.bincount(actual_labels).argmax() if len(actual_labels) > 0 else 0
                    decoded_actual = decode_activity(actual_label)

                    # Store results for accuracy later
                    if actual_label != 0:
                        all_actual.append(actual_label)
                        all_predicted.append(predicted_label)

                    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                    match = "✅" if predicted_label == actual_label else "❌"

                    print(f"🪟 Rows {last_row_read+1}-{last_row_read+window_size} → "
                          f"Predicted: {decoded_pred} ({predicted_label}) | "
                          f"Actual: {decoded_actual} ({actual_label}) {match} | "
                          f"Latency: {latency_ms} ms")

                    with open(output_log, "a") as f:
                        f.write(f"{timestamp},{decoded_actual},{decoded_pred},{latency_ms},{int(predicted_label == actual_label)}\n")

                    last_row_read += stride

            time.sleep(1 / sampling_rate)

    except KeyboardInterrupt:
        print("\n⛔ Stopped by user.")
        if all_actual:
            acc = accuracy_score(all_actual, all_predicted) * 100
            print(f"\n Final Accuracy: {acc:.2f}% "
                  f"({len(all_actual)} evaluated windows)")
        else:
            print("\n⚠️ No valid windows evaluated. Accuracy cannot be computed.")


if __name__ == "__main__":
    live_predict()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📡 Monitoring for new data in sliding windows...
# Press Ctrl+C to stop.
#
# 🪟 Rows 1-60 → Skipped (Label 0)
# 🪟 Rows 61-120 → Skipped (Label 0)
# 🪟 Rows 121-180 → Skipped (Label 0)
# 🪟 Rows 181-240 → Skipped (Label 0)
# 🪟 Rows 241-300 → Skipped (Label 0)
# 🪟 Rows 301-360 → Skipped (Label 0)
# 🪟 Rows 361-420 → Skipped (Label 0)
# 🪟 Rows 421-480 → Skipped (Label 0)
# 🪟 Rows 481-540 → Skipped (Label 0)
# 🪟 Rows 541-600 → Skipped (Label 0)
# 🪟 Rows 601-660 → Skipped (Label 0)
# 🪟 Rows 661-720 → Skipped (Label 0)
# 🪟 Rows 721-780 → Skipped (Label 0)
# 🪟 Rows 781-840 → Skipped (Label 0)
# 🪟 Rows 841-900 → Skipped (Label 0)
# 🪟 Rows 901-960 → Skipped (Label 0)
# 🪟 Rows 961-1020 → Skipped (Label 0)
# 🪟 Rows 1021-1080 → Skipped (Label 0)
# 🪟 Rows 1081-1140 → Skipped (Label 0)
# 🪟 Rows 1141-1200 → Skipped (Label 0)
# 🪟 Rows 1201-1260 → Skipped (Label 0)
# 🪟 Rows 1261-1320 → Skipped (Label 0)
# 🪟 Rows 1321-1380 → Skipped (Label 0)
# 🪟 Rows 1381-1440 → Skipped (Label 0)
# 🪟 Rows 1441-1500 → Skipped (Label 0)
# 🪟 Rows 1501-1560 → Skipped (Label 0)
# 🪟 Rows 1561-1620 → Skipped (Label 0)
# 🪟 Rows 1621-1680 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 163.84 ms
# 🪟 Rows 1681-1740 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 123.8 ms
# 🪟 Rows 1741-1800 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 82.93 ms
# 🪟 Rows 1801-1860 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 127.24 ms
# 🪟 Rows 1861-1920 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 82.13 ms
# 🪟 Rows 1921-1980 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 78.32 ms
# 🪟 Rows 1981-2040 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 80.83 ms
# 🪟 Rows 2041-2100 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 76.11 ms
# 🪟 Rows 2101-2160 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 85.66 ms
# 🪟 Rows 2161-2220 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 89.82 ms
# 🪟 Rows 2221-2280 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 81.71 ms
# 🪟 Rows 2281-2340 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 120.14 ms
# 🪟 Rows 2341-2400 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 85.8 ms
# 🪟 Rows 2401-2460 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 81.38 ms
# 🪟 Rows 2461-2520 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 122.58 ms
# 🪟 Rows 2521-2580 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 82.06 ms
# 🪟 Rows 2581-2640 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 78.41 ms
# 🪟 Rows 2641-2700 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 85.42 ms
# 🪟 Rows 2701-2760 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 78.25 ms
# 🪟 Rows 2761-2820 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 77.86 ms
# 🪟 Rows 2821-2880 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 90.34 ms
# 🪟 Rows 2881-2940 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 135.25 ms
# 🪟 Rows 2941-3000 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 159.01 ms
# 🪟 Rows 3001-3060 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 150.34 ms
# 🪟 Rows 3061-3120 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 173.56 ms
# 🪟 Rows 3121-3180 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 142.32 ms
# 🪟 Rows 3181-3240 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 152.88 ms
# 🪟 Rows 3241-3300 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 142.43 ms
# 🪟 Rows 3301-3360 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 148.45 ms
# 🪟 Rows 3361-3420 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 109.62 ms
# 🪟 Rows 3421-3480 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 143.29 ms
# 🪟 Rows 3481-3540 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 157.44 ms
# 🪟 Rows 3541-3600 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 163.04 ms
# 🪟 Rows 3601-3660 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 122.46 ms
# 🪟 Rows 3661-3720 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 153.38 ms
# 🪟 Rows 3721-3780 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 149.28 ms
# 🪟 Rows 3781-3840 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 153.15 ms
# 🪟 Rows 3841-3900 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 120.81 ms
# 🪟 Rows 3901-3960 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 161.79 ms
# 🪟 Rows 3961-4020 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 147.95 ms
# 🪟 Rows 4021-4080 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 149.18 ms
# 🪟 Rows 4081-4140 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 155.3 ms
# 🪟 Rows 4141-4200 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 161.69 ms
# 🪟 Rows 4201-4260 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 154.14 ms
# 🪟 Rows 4261-4320 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 128.84 ms
# 🪟 Rows 4321-4380 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 174.99 ms
# 🪟 Rows 4381-4440 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 154.53 ms
# 🪟 Rows 4441-4500 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 155.1 ms
# 🪟 Rows 4501-4560 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 157.17 ms
# 🪟 Rows 4561-4620 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 81.56 ms
# 🪟 Rows 4621-4680 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 82.01 ms
# 🪟 Rows 4681-4740 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 85.34 ms
# 🪟 Rows 4741-4800 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 81.23 ms
# 🪟 Rows 4801-4860 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 78.91 ms
# 🪟 Rows 4861-4920 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 123.41 ms
# 🪟 Rows 4921-4980 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 119.34 ms
# 🪟 Rows 4981-5040 → Skipped (Label 0)
# 🪟 Rows 5041-5100 → Predicted: Walking (1) | Actual: Unknown (6) ❌ | Latency: 94.22 ms
# 🪟 Rows 5101-5160 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 123.85 ms
# 🪟 Rows 5161-5220 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 85.88 ms
# 🪟 Rows 5221-5280 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 83.71 ms
# 🪟 Rows 5281-5340 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 85.11 ms
# 🪟 Rows 5341-5400 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 89.1 ms
# 🪟 Rows 5401-5460 → Predicted: Walking (1) | Actual: Unknown (6) ❌ | Latency: 123.47 ms
# 🪟 Rows 5461-5520 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 83.83 ms
# 🪟 Rows 5521-5580 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 123.04 ms
# 🪟 Rows 5581-5640 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 107.93 ms
# 🪟 Rows 5641-5700 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 77.7 ms
# 🪟 Rows 5701-5760 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 77.64 ms
# 🪟 Rows 5761-5820 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 87.29 ms
# 🪟 Rows 5821-5880 → Predicted: Walking (1) | Actual: Unknown (6) ❌ | Latency: 80.57 ms
# 🪟 Rows 5881-5940 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 79.88 ms
# 🪟 Rows 5941-6000 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 123.28 ms
# 🪟 Rows 6001-6060 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 125.97 ms
# 🪟 Rows 6061-6120 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 95.25 ms
# 🪟 Rows 6121-6180 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 82.57 ms
# 🪟 Rows 6181-6240 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 94.8 ms
# 🪟 Rows 6241-6300 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 81.88 ms
# 🪟 Rows 6301-6360 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 78.64 ms
# 🪟 Rows 6361-6420 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 79.08 ms
# 🪟 Rows 6421-6480 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 80.45 ms
# 🪟 Rows 6481-6540 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 92.23 ms
# 🪟 Rows 6541-6600 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 82.94 ms
# 🪟 Rows 6601-6660 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 90.6 ms
# 🪟 Rows 6661-6720 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 85.94 ms
# 🪟 Rows 6721-6780 → Skipped (Label 0)
# 🪟 Rows 6781-6840 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 127.83 ms
# 🪟 Rows 6841-6900 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 83.0 ms
# 🪟 Rows 6901-6960 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 126.55 ms
# 🪟 Rows 6961-7020 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 99.2 ms
# 🪟 Rows 7021-7080 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 121.47 ms
# 🪟 Rows 7081-7140 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 79.63 ms
# 🪟 Rows 7141-7200 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 119.63 ms
# 🪟 Rows 7201-7260 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 126.09 ms
# 🪟 Rows 7261-7320 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 94.57 ms
# 🪟 Rows 7321-7380 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 125.78 ms
# 🪟 Rows 7381-7440 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 85.05 ms
# 🪟 Rows 7441-7500 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 121.52 ms
# 🪟 Rows 7501-7560 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 84.32 ms
# 🪟 Rows 7561-7620 → Predicted: Sitting (3) | Actual: Unknown (6) ❌ | Latency: 78.8 ms
# 🪟 Rows 7621-7680 → Predicted: Walking (1) | Actual: Stairs (5) ❌ | Latency: 80.54 ms
# 🪟 Rows 7681-7740 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 79.78 ms
# 🪟 Rows 7741-7800 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 80.64 ms
# 🪟 Rows 7801-7860 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 79.64 ms
# 🪟 Rows 7861-7920 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 86.67 ms
# 🪟 Rows 7921-7980 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 81.82 ms
# 🪟 Rows 7981-8040 → Skipped (Label 0)
# 🪟 Rows 8041-8100 → Skipped (Label 0)
# 🪟 Rows 8101-8160 → Skipped (Label 0)
# 🪟 Rows 8161-8220 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 93.48 ms
# 🪟 Rows 8221-8280 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 87.14 ms
# 🪟 Rows 8281-8340 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 82.17 ms
# 🪟 Rows 8341-8400 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 97.38 ms
# 🪟 Rows 8401-8460 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 85.92 ms
# 🪟 Rows 8461-8520 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 81.61 ms
# 🪟 Rows 8521-8580 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 79.12 ms
# 🪟 Rows 8581-8640 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 82.97 ms
# 🪟 Rows 8641-8700 → Predicted: Sitting (3) | Actual: Stairs (5) ❌ | Latency: 78.61 ms
# 🪟 Rows 8701-8760 → Skipped (Label 0)
# 🪟 Rows 8761-8820 → Skipped (Label 0)
# 🪟 Rows 8821-8880 → Skipped (Label 0)
# 🪟 Rows 8881-8940 → Skipped (Label 0)
# 🪟 Rows 8941-9000 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 78.33 ms
# 🪟 Rows 9001-9060 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 84.26 ms
# 🪟 Rows 9061-9120 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 78.76 ms
# 🪟 Rows 9121-9180 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 124.93 ms
# 🪟 Rows 9181-9240 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 83.37 ms
# 🪟 Rows 9241-9300 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 87.98 ms
# 🪟 Rows 9301-9360 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 98.85 ms
# 🪟 Rows 9361-9420 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 81.32 ms
# 🪟 Rows 9421-9480 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 81.96 ms
# 🪟 Rows 9481-9540 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 84.06 ms
# 🪟 Rows 9541-9600 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 80.33 ms
# 🪟 Rows 9601-9660 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 78.86 ms
# 🪟 Rows 9661-9720 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 82.89 ms
# 🪟 Rows 9721-9780 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 79.66 ms
# 🪟 Rows 9781-9840 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 78.49 ms
# 🪟 Rows 9841-9900 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 88.76 ms
# 🪟 Rows 9901-9960 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 82.1 ms
# 🪟 Rows 9961-10020 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 87.49 ms
# 🪟 Rows 10021-10080 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 137.34 ms
# 🪟 Rows 10081-10140 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 83.77 ms
# 🪟 Rows 10141-10200 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 121.98 ms
# 🪟 Rows 10201-10260 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 81.23 ms
# 🪟 Rows 10261-10320 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 79.01 ms
# 🪟 Rows 10321-10380 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 85.85 ms
# 🪟 Rows 10381-10440 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 118.29 ms
# 🪟 Rows 10441-10500 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 79.04 ms
# 🪟 Rows 10501-10560 → Skipped (Label 0)
# 🪟 Rows 10561-10620 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 77.77 ms
# 🪟 Rows 10621-10680 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 127.26 ms
# 🪟 Rows 10681-10740 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 131.21 ms
# 🪟 Rows 10741-10800 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 86.49 ms
# 🪟 Rows 10801-10860 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 84.24 ms
# 🪟 Rows 10861-10920 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 121.53 ms
# 🪟 Rows 10921-10980 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 85.15 ms
# 🪟 Rows 10981-11040 → Predicted: Sitting (3) | Actual: Jogging (2) ❌ | Latency: 82.31 ms
# 🪟 Rows 11041-11100 → Skipped (Label 0)
# 🪟 Rows 11101-11160 → Skipped (Label 0)
# 🪟 Rows 11161-11220 → Skipped (Label 0)
# 🪟 Rows 11221-11280 → Skipped (Label 0)
# 🪟 Rows 11281-11340 → Skipped (Label 0)
# 🪟 Rows 11341-11400 → Skipped (Label 0)
# 🪟 Rows 11401-11460 → Skipped (Label 0)
# 🪟 Rows 11461-11520 → Skipped (Label 0)
# 🪟 Rows 11521-11580 → Skipped (Label 0)
# 🪟 Rows 11581-11640 → Skipped (Label 0)
# 🪟 Rows 11641-11700 → Skipped (Label 0)
# 🪟 Rows 11701-11760 → Skipped (Label 0)
# 🪟 Rows 11761-11820 → Skipped (Label 0)
# 🪟 Rows 11821-11880 → Skipped (Label 0)
# 🪟 Rows 11881-11940 → Skipped (Label 0)
# 🪟 Rows 11941-12000 → Skipped (Label 0)
# 🪟 Rows 12001-12060 → Skipped (Label 0)
# 🪟 Rows 12061-12120 → Skipped (Label 0)
# 🪟 Rows 12121-12180 → Skipped (Label 0)
# 🪟 Rows 12181-12240 → Skipped (Label 0)
# 🪟 Rows 12241-12300 → Skipped (Label 0)
# 🪟 Rows 12301-12360 → Skipped (Label 0)
# 🪟 Rows 12361-12420 → Skipped (Label 0)
# 🪟 Rows 12421-12480 → Skipped (Label 0)
# 🪟 Rows 12481-12540 → Skipped (Label 0)
# 🪟 Rows 12541-12600 → Skipped (Label 0)
# 🪟 Rows 12601-12660 → Skipped (Label 0)
# 🪟 Rows 12661-12720 → Skipped (Label 0)
# 🪟 Rows 12721-12780 → Skipped (Label 0)
# 🪟 Rows 12781-12840 → Skipped (Label 0)
# 🪟 Rows 12841-12900 → Skipped (Label 0)
# 🪟 Rows 12901-12960 → Skipped (Label 0)
# 🪟 Rows 12961-13020 → Skipped (Label 0)
# 🪟 Rows 13021-13080 → Skipped (Label 0)
# 🪟 Rows 13081-13140 → Skipped (Label 0)
# 🪟 Rows 13141-13200 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 87.4 ms
# 🪟 Rows 13201-13260 → Predicted: Standing (4) | Actual: Sitting (3) ❌ | Latency: 78.54 ms
# 🪟 Rows 13261-13320 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 79.59 ms
# 🪟 Rows 13321-13380 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 82.02 ms
# 🪟 Rows 13381-13440 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 77.84 ms
# 🪟 Rows 13441-13500 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 125.02 ms
# 🪟 Rows 13501-13560 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 83.98 ms
# 🪟 Rows 13561-13620 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 153.03 ms
# 🪟 Rows 13621-13680 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 154.8 ms
# 🪟 Rows 13681-13740 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 151.62 ms
# 🪟 Rows 13741-13800 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 143.59 ms
# 🪟 Rows 13801-13860 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 120.92 ms
# 🪟 Rows 13861-13920 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 143.25 ms
# 🪟 Rows 13921-13980 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 173.42 ms
# 🪟 Rows 13981-14040 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 145.34 ms
# 🪟 Rows 14041-14100 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 122.68 ms
# 🪟 Rows 14101-14160 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 148.01 ms
# 🪟 Rows 14161-14220 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 162.87 ms
# 🪟 Rows 14221-14280 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 144.41 ms
# 🪟 Rows 14281-14340 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 154.88 ms
# 🪟 Rows 14341-14400 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 178.58 ms
# 🪟 Rows 14401-14460 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 150.85 ms
# 🪟 Rows 14461-14520 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 119.11 ms
# 🪟 Rows 14521-14580 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 735.4 ms
# 🪟 Rows 14581-14640 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 148.25 ms
# 🪟 Rows 14641-14700 → Predicted: Standing (4) | Actual: Sitting (3) ❌ | Latency: 163.71 ms
# 🪟 Rows 14701-14760 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 150.88 ms
# 🪟 Rows 14761-14820 → Predicted: Standing (4) | Actual: Sitting (3) ❌ | Latency: 156.8 ms
# 🪟 Rows 14821-14880 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 150.58 ms
# 🪟 Rows 14881-14940 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 165.51 ms
# 🪟 Rows 14941-15000 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 189.93 ms
# 🪟 Rows 15001-15060 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 121.46 ms
# 🪟 Rows 15061-15120 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 81.65 ms
# 🪟 Rows 15121-15180 → Predicted: Sitting (3) | Actual: Standing (4) ❌ | Latency: 80.75 ms
# 🪟 Rows 15181-15240 → Predicted: Sitting (3) | Actual: Standing (4) ❌ | Latency: 89.79 ms
# 🪟 Rows 15241-15300 → Predicted: Walking (1) | Actual: Standing (4) ❌ | Latency: 78.31 ms
# 🪟 Rows 15301-15360 → Predicted: Sitting (3) | Actual: Standing (4) ❌ | Latency: 120.74 ms
# 🪟 Rows 15361-15420 → Predicted: Sitting (3) | Actual: Standing (4) ❌ | Latency: 197.73 ms
# 🪟 Rows 15421-15480 → Predicted: Sitting (3) | Actual: Standing (4) ❌ | Latency: 202.62 ms
# 🪟 Rows 15481-15540 → Predicted: Sitting (3) | Actual: Standing (4) ❌ | Latency: 82.07 ms
# 🪟 Rows 15541-15600 → Predicted: Sitting (3) | Actual: Standing (4) ❌ | Latency: 78.28 ms

# %% [markdown]
# #LSTM (Predict_LOG)

# %%
import os
import time
import numpy as np
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model


csv_file = "/content/drive/MyDrive/HAR Data & Models/sb_IMU.csv"
model_path = "/content/drive/MyDrive/HAR Data & Models/best_lstm_model.h5"
output_log = "LSTM.csv"

window_size = 60
stride = 60
sampling_rate = 30
features = ['Acc_X', 'Acc_Y', 'Acc_Z', 'Gyro_X', 'Gyro_Y', 'Gyro_Z']
label_column = "Label"

categories = [1, 2, 3, 4, 5, 6]

def decode_activity(label):
    mapping = {
        1: "Walking",
        2: "Running",
        3: "Sitting",
        4: "Standing",
        5: "Stair Down",
        6: "Stair Up"
    }
    return mapping.get(label, "Unknown")


def normalize_segment(segment_array):
    """
    Normalize each feature (column) across the 60 timesteps.
    Keeps the shape (60, 6) for Conv1D.
    """
    scaler = StandardScaler()
    normalized = scaler.fit_transform(segment_array)  # shape (60, 6)
    return normalized


if not os.path.exists(output_log):
    with open(output_log, "w") as f:
        f.write("Timestamp,Actual_Label,Predicted_Label,Latency(ms),Valid\n")


model = load_model(model_path)

def live_predict():
    print("📡 Monitoring for new data in sliding windows...\nPress Ctrl+C to stop.\n")
    last_row_read = 0

    try:
        while True:
            if not os.path.exists(csv_file):
                print(f"Waiting for file {csv_file} to appear...")
                time.sleep(1)
                continue

            df = pd.read_csv(csv_file)

            # Ensure necessary columns exist
            if not all(col in df.columns for col in features + [label_column]):
                print("Missing required columns. Waiting...")
                time.sleep(1)
                continue

            total_rows = len(df)

            if total_rows >= window_size:
                while last_row_read + window_size <= total_rows:
                    window = df.iloc[last_row_read:last_row_read + window_size]
                    actual_labels = window[label_column].values

                    # Skip windows with all labels = 0
                    if np.all(actual_labels == 0):
                        print(f"🪟 Rows {last_row_read+1}-{last_row_read+window_size} → Skipped (Label 0)")
                        last_row_read += stride
                        continue

                    # Apply preprocessing
                    feature_chunk = window[features].values  # (60, 6)
                    norm_chunk = normalize_segment(feature_chunk)  # (60, 6)

                    # Model expects (1, 60, 6)
                    X_input = norm_chunk[np.newaxis, ...]

                    # Prediction
                    start_time = time.time()
                    prediction = model.predict(X_input, verbose=0)[0]
                    latency_ms = round((time.time() - start_time) * 1000, 2)

                    predicted_label = categories[np.argmax(prediction)]
                    decoded_pred = decode_activity(predicted_label)

                    # Actual label = majority vote in window
                    actual_labels = actual_labels[actual_labels != 0]
                    actual_label = np.bincount(actual_labels).argmax() if len(actual_labels) > 0 else 0
                    decoded_actual = decode_activity(actual_label)

                    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                    match = "✅" if predicted_label == actual_label else "❌"

                    print(f"🪟 Rows {last_row_read+1}-{last_row_read+window_size} → "
                          f"Predicted: {decoded_pred} ({predicted_label}) | "
                          f"Actual: {decoded_actual} ({actual_label}) {match} | "
                          f"Latency: {latency_ms} ms")

                    # Save log
                    with open(output_log, "a") as f:
                        f.write(f"{timestamp},{decoded_actual},{decoded_pred},{latency_ms},{int(predicted_label == actual_label)}\n")

                    last_row_read += stride

            time.sleep(1 / sampling_rate)

    except KeyboardInterrupt:
        print("\n⛔ Stopped by user.")

if __name__ == "__main__":
    live_predict()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📡 Monitoring for new data in sliding windows...
# Press Ctrl+C to stop.
#
# 🪟 Rows 1-60 → Skipped (Label 0)
# 🪟 Rows 61-120 → Skipped (Label 0)
# 🪟 Rows 121-180 → Skipped (Label 0)
# 🪟 Rows 181-240 → Skipped (Label 0)
# 🪟 Rows 241-300 → Skipped (Label 0)
# 🪟 Rows 301-360 → Skipped (Label 0)
# 🪟 Rows 361-420 → Skipped (Label 0)
# 🪟 Rows 421-480 → Skipped (Label 0)
# 🪟 Rows 481-540 → Skipped (Label 0)
# 🪟 Rows 541-600 → Skipped (Label 0)
# 🪟 Rows 601-660 → Skipped (Label 0)
# 🪟 Rows 661-720 → Skipped (Label 0)
# 🪟 Rows 721-780 → Skipped (Label 0)
# 🪟 Rows 781-840 → Skipped (Label 0)
# 🪟 Rows 841-900 → Skipped (Label 0)
# 🪟 Rows 901-960 → Skipped (Label 0)
# 🪟 Rows 961-1020 → Skipped (Label 0)
# 🪟 Rows 1021-1080 → Skipped (Label 0)
# 🪟 Rows 1081-1140 → Skipped (Label 0)
# 🪟 Rows 1141-1200 → Skipped (Label 0)
# 🪟 Rows 1201-1260 → Skipped (Label 0)
# 🪟 Rows 1261-1320 → Skipped (Label 0)
# 🪟 Rows 1321-1380 → Skipped (Label 0)
# 🪟 Rows 1381-1440 → Skipped (Label 0)
# 🪟 Rows 1441-1500 → Skipped (Label 0)
# 🪟 Rows 1501-1560 → Skipped (Label 0)
# 🪟 Rows 1561-1620 → Skipped (Label 0)
# 🪟 Rows 1621-1680 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 361.75 ms
# 🪟 Rows 1681-1740 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 117.23 ms
# 🪟 Rows 1741-1800 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 117.26 ms
# 🪟 Rows 1801-1860 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.54 ms
# 🪟 Rows 1861-1920 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.58 ms
# 🪟 Rows 1921-1980 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 108.85 ms
# 🪟 Rows 1981-2040 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 152.47 ms
# 🪟 Rows 2041-2100 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 524.76 ms
# 🪟 Rows 2101-2160 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 136.57 ms
# 🪟 Rows 2161-2220 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 143.28 ms
# 🪟 Rows 2221-2280 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 110.83 ms
# 🪟 Rows 2281-2340 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 133.13 ms
# 🪟 Rows 2341-2400 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 144.99 ms
# 🪟 Rows 2401-2460 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 112.46 ms
# 🪟 Rows 2461-2520 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 142.01 ms
# 🪟 Rows 2521-2580 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 112.65 ms
# 🪟 Rows 2581-2640 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 133.72 ms
# 🪟 Rows 2641-2700 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 157.49 ms
# 🪟 Rows 2701-2760 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 137.77 ms
# 🪟 Rows 2761-2820 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 149.95 ms
# 🪟 Rows 2821-2880 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 147.95 ms
# 🪟 Rows 2881-2940 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 118.44 ms
# 🪟 Rows 2941-3000 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 149.31 ms
# 🪟 Rows 3001-3060 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 137.68 ms
# 🪟 Rows 3061-3120 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 152.64 ms
# 🪟 Rows 3121-3180 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 148.03 ms
# 🪟 Rows 3181-3240 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 149.58 ms
# 🪟 Rows 3241-3300 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 125.2 ms
# 🪟 Rows 3301-3360 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.53 ms
# 🪟 Rows 3361-3420 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 89.02 ms
# 🪟 Rows 3421-3480 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 86.06 ms
# 🪟 Rows 3481-3540 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 80.32 ms
# 🪟 Rows 3541-3600 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 84.83 ms
# 🪟 Rows 3601-3660 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 88.13 ms
# 🪟 Rows 3661-3720 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.88 ms
# 🪟 Rows 3721-3780 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.21 ms
# 🪟 Rows 3781-3840 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 118.57 ms
# 🪟 Rows 3841-3900 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 79.17 ms
# 🪟 Rows 3901-3960 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 92.23 ms
# 🪟 Rows 3961-4020 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 80.48 ms
# 🪟 Rows 4021-4080 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 115.87 ms
# 🪟 Rows 4081-4140 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 121.38 ms
# 🪟 Rows 4141-4200 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 89.02 ms
# 🪟 Rows 4201-4260 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 119.71 ms
# 🪟 Rows 4261-4320 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 123.67 ms
# 🪟 Rows 4321-4380 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 121.11 ms
# 🪟 Rows 4381-4440 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 118.11 ms
# 🪟 Rows 4441-4500 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 97.6 ms
# 🪟 Rows 4501-4560 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 81.18 ms
# 🪟 Rows 4561-4620 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.56 ms
# 🪟 Rows 4621-4680 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.71 ms
# 🪟 Rows 4681-4740 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.23 ms
# 🪟 Rows 4741-4800 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.45 ms
# 🪟 Rows 4801-4860 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 126.34 ms
# 🪟 Rows 4861-4920 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 89.53 ms
# 🪟 Rows 4921-4980 → Predicted: Stair Down (5) | Actual: Walking (1) ❌ | Latency: 119.89 ms
# 🪟 Rows 4981-5040 → Skipped (Label 0)
# 🪟 Rows 5041-5100 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 81.36 ms
# 🪟 Rows 5101-5160 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 118.52 ms
# 🪟 Rows 5161-5220 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 126.39 ms
# 🪟 Rows 5221-5280 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 77.28 ms
# 🪟 Rows 5281-5340 → Predicted: Running (2) | Actual: Stair Up (6) ❌ | Latency: 114.67 ms
# 🪟 Rows 5341-5400 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 116.52 ms
# 🪟 Rows 5401-5460 → Predicted: Standing (4) | Actual: Stair Up (6) ❌ | Latency: 75.87 ms
# 🪟 Rows 5461-5520 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 81.61 ms
# 🪟 Rows 5521-5580 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 87.68 ms
# 🪟 Rows 5581-5640 → Predicted: Stair Down (5) | Actual: Stair Up (6) ❌ | Latency: 92.37 ms
# 🪟 Rows 5641-5700 → Predicted: Stair Down (5) | Actual: Stair Up (6) ❌ | Latency: 88.91 ms
# 🪟 Rows 5701-5760 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 91.19 ms
# 🪟 Rows 5761-5820 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 83.41 ms
# 🪟 Rows 5821-5880 → Predicted: Stair Down (5) | Actual: Stair Up (6) ❌ | Latency: 93.41 ms
# 🪟 Rows 5881-5940 → Predicted: Stair Up (6) | Actual: Stair Down (5) ❌ | Latency: 79.87 ms
# 🪟 Rows 5941-6000 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 79.34 ms
# 🪟 Rows 6001-6060 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 77.29 ms
# 🪟 Rows 6061-6120 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 119.79 ms
# 🪟 Rows 6121-6180 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 79.2 ms
# 🪟 Rows 6181-6240 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 121.74 ms
# 🪟 Rows 6241-6300 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 77.3 ms
# 🪟 Rows 6301-6360 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 90.71 ms
# 🪟 Rows 6361-6420 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 84.44 ms
# 🪟 Rows 6421-6480 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 80.89 ms
# 🪟 Rows 6481-6540 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 122.44 ms
# 🪟 Rows 6541-6600 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 85.67 ms
# 🪟 Rows 6601-6660 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 81.45 ms
# 🪟 Rows 6661-6720 → Predicted: Standing (4) | Actual: Stair Down (5) ❌ | Latency: 80.55 ms
# 🪟 Rows 6721-6780 → Skipped (Label 0)
# 🪟 Rows 6781-6840 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 81.28 ms
# 🪟 Rows 6841-6900 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 122.01 ms
# 🪟 Rows 6901-6960 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 76.91 ms
# 🪟 Rows 6961-7020 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 79.77 ms
# 🪟 Rows 7021-7080 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 119.95 ms
# 🪟 Rows 7081-7140 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 128.16 ms
# 🪟 Rows 7141-7200 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 85.78 ms
# 🪟 Rows 7201-7260 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 98.99 ms
# 🪟 Rows 7261-7320 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 117.88 ms
# 🪟 Rows 7321-7380 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 81.51 ms
# 🪟 Rows 7381-7440 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 88.77 ms
# 🪟 Rows 7441-7500 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 90.61 ms
# 🪟 Rows 7501-7560 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 79.27 ms
# 🪟 Rows 7561-7620 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 79.66 ms
# 🪟 Rows 7621-7680 → Predicted: Stair Up (6) | Actual: Stair Down (5) ❌ | Latency: 86.76 ms
# 🪟 Rows 7681-7740 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 80.19 ms
# 🪟 Rows 7741-7800 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 78.17 ms
# 🪟 Rows 7801-7860 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 90.94 ms
# 🪟 Rows 7861-7920 → Predicted: Walking (1) | Actual: Stair Down (5) ❌ | Latency: 100.69 ms
# 🪟 Rows 7921-7980 → Predicted: Sitting (3) | Actual: Stair Down (5) ❌ | Latency: 83.69 ms
# 🪟 Rows 7981-8040 → Skipped (Label 0)
# 🪟 Rows 8041-8100 → Skipped (Label 0)
# 🪟 Rows 8101-8160 → Skipped (Label 0)
# 🪟 Rows 8161-8220 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 119.44 ms
# 🪟 Rows 8221-8280 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 120.76 ms
# 🪟 Rows 8281-8340 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 84.16 ms
# 🪟 Rows 8341-8400 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 80.61 ms
# 🪟 Rows 8401-8460 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 118.92 ms
# 🪟 Rows 8461-8520 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 78.45 ms
# 🪟 Rows 8521-8580 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 76.29 ms
# 🪟 Rows 8581-8640 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 80.88 ms
# 🪟 Rows 8641-8700 → Predicted: Stair Up (6) | Actual: Stair Down (5) ❌ | Latency: 76.24 ms
# 🪟 Rows 8701-8760 → Skipped (Label 0)
# 🪟 Rows 8761-8820 → Skipped (Label 0)
# 🪟 Rows 8821-8880 → Skipped (Label 0)
# 🪟 Rows 8881-8940 → Skipped (Label 0)
# 🪟 Rows 8941-9000 → Predicted: Standing (4) | Actual: Running (2) ❌ | Latency: 132.49 ms
# 🪟 Rows 9001-9060 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 82.99 ms
# 🪟 Rows 9061-9120 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 79.65 ms
# 🪟 Rows 9121-9180 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 88.65 ms
#
# ⛔ Stopped by user.

# %% [markdown]
# #LSTM + 1D_CNN (Predict_LOG)

# %%
import os
import time
import numpy as np
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model


csv_file = "/content/drive/MyDrive/HAR Data & Models/sb_IMU.csv"
model_path = "/content/drive/MyDrive/HAR Data & Models/best_cnn_lstm_model.h5"
output_log = "LSTM_CNN.csv"

window_size = 60
stride = 60
sampling_rate = 30
features = ['Acc_X', 'Acc_Y', 'Acc_Z', 'Gyro_X', 'Gyro_Y', 'Gyro_Z']
label_column = "Label"

categories = [1, 2, 3, 4, 5, 6]

def decode_activity(label):
    mapping = {
        1: "Walking",
        2: "Running",
        3: "Sitting",
        4: "Standing",
        5: "Stair Down",
        6: "Stair Up"
    }
    return mapping.get(label, "Unknown")


def normalize_segment(segment_array):
    """
    Normalize each feature (column) across the 60 timesteps.
    Keeps the shape (60, 6) for Conv1D.
    """
    scaler = StandardScaler()
    normalized = scaler.fit_transform(segment_array)  # shape (60, 6)
    return normalized


if not os.path.exists(output_log):
    with open(output_log, "w") as f:
        f.write("Timestamp,Actual_Label,Predicted_Label,Latency(ms),Valid\n")


model = load_model(model_path)

def live_predict():
    print("📡 Monitoring for new data in sliding windows...\nPress Ctrl+C to stop.\n")
    last_row_read = 0

    try:
        while True:
            if not os.path.exists(csv_file):
                print(f"Waiting for file {csv_file} to appear...")
                time.sleep(1)
                continue

            df = pd.read_csv(csv_file)

            # Ensure necessary columns exist
            if not all(col in df.columns for col in features + [label_column]):
                print("Missing required columns. Waiting...")
                time.sleep(1)
                continue

            total_rows = len(df)

            if total_rows >= window_size:
                while last_row_read + window_size <= total_rows:
                    window = df.iloc[last_row_read:last_row_read + window_size]
                    actual_labels = window[label_column].values

                    # Skip windows with all labels = 0
                    if np.all(actual_labels == 0):
                        print(f"🪟 Rows {last_row_read+1}-{last_row_read+window_size} → Skipped (Label 0)")
                        last_row_read += stride
                        continue

                    # Apply preprocessing
                    feature_chunk = window[features].values  # (60, 6)
                    norm_chunk = normalize_segment(feature_chunk)  # (60, 6)

                    # Model expects (1, 60, 6)
                    X_input = norm_chunk[np.newaxis, ...]

                    # Prediction
                    start_time = time.time()
                    prediction = model.predict(X_input, verbose=0)[0]
                    latency_ms = round((time.time() - start_time) * 1000, 2)

                    predicted_label = categories[np.argmax(prediction)]
                    decoded_pred = decode_activity(predicted_label)

                    # Actual label = majority vote in window
                    actual_labels = actual_labels[actual_labels != 0]
                    actual_label = np.bincount(actual_labels).argmax() if len(actual_labels) > 0 else 0
                    decoded_actual = decode_activity(actual_label)

                    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                    match = "✅" if predicted_label == actual_label else "❌"

                    print(f"🪟 Rows {last_row_read+1}-{last_row_read+window_size} → "
                          f"Predicted: {decoded_pred} ({predicted_label}) | "
                          f"Actual: {decoded_actual} ({actual_label}) {match} | "
                          f"Latency: {latency_ms} ms")

                    # Save log
                    with open(output_log, "a") as f:
                        f.write(f"{timestamp},{decoded_actual},{decoded_pred},{latency_ms},{int(predicted_label == actual_label)}\n")

                    last_row_read += stride

            time.sleep(1 / sampling_rate)

    except KeyboardInterrupt:
        print("\n⛔ Stopped by user.")

if __name__ == "__main__":
    live_predict()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📡 Monitoring for new data in sliding windows...
# Press Ctrl+C to stop.
#
# 🪟 Rows 1-60 → Skipped (Label 0)
# 🪟 Rows 61-120 → Skipped (Label 0)
# 🪟 Rows 121-180 → Skipped (Label 0)
# 🪟 Rows 181-240 → Skipped (Label 0)
# 🪟 Rows 241-300 → Skipped (Label 0)
# 🪟 Rows 301-360 → Skipped (Label 0)
# 🪟 Rows 361-420 → Skipped (Label 0)
# 🪟 Rows 421-480 → Skipped (Label 0)
# 🪟 Rows 481-540 → Skipped (Label 0)
# 🪟 Rows 541-600 → Skipped (Label 0)
# 🪟 Rows 601-660 → Skipped (Label 0)
# 🪟 Rows 661-720 → Skipped (Label 0)
# 🪟 Rows 721-780 → Skipped (Label 0)
# 🪟 Rows 781-840 → Skipped (Label 0)
# 🪟 Rows 841-900 → Skipped (Label 0)
# 🪟 Rows 901-960 → Skipped (Label 0)
# 🪟 Rows 961-1020 → Skipped (Label 0)
# 🪟 Rows 1021-1080 → Skipped (Label 0)
# 🪟 Rows 1081-1140 → Skipped (Label 0)
# 🪟 Rows 1141-1200 → Skipped (Label 0)
# 🪟 Rows 1201-1260 → Skipped (Label 0)
# 🪟 Rows 1261-1320 → Skipped (Label 0)
# 🪟 Rows 1321-1380 → Skipped (Label 0)
# 🪟 Rows 1381-1440 → Skipped (Label 0)
# 🪟 Rows 1441-1500 → Skipped (Label 0)
# 🪟 Rows 1501-1560 → Skipped (Label 0)
# 🪟 Rows 1561-1620 → Skipped (Label 0)
# 🪟 Rows 1621-1680 → Predicted: Stair Down (5) | Actual: Walking (1) ❌ | Latency: 361.84 ms
# 🪟 Rows 1681-1740 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.86 ms
# 🪟 Rows 1741-1800 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.03 ms
# 🪟 Rows 1801-1860 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 92.34 ms
# 🪟 Rows 1861-1920 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.5 ms
# 🪟 Rows 1921-1980 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 73.98 ms
# 🪟 Rows 1981-2040 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.06 ms
# 🪟 Rows 2041-2100 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 72.35 ms
# 🪟 Rows 2101-2160 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 85.24 ms
# 🪟 Rows 2161-2220 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 85.31 ms
# 🪟 Rows 2221-2280 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 73.2 ms
# 🪟 Rows 2281-2340 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 73.63 ms
# 🪟 Rows 2341-2400 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.56 ms
# 🪟 Rows 2401-2460 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 72.64 ms
# 🪟 Rows 2461-2520 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 71.65 ms
# 🪟 Rows 2521-2580 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 78.66 ms
# 🪟 Rows 2581-2640 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 89.62 ms
# 🪟 Rows 2641-2700 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 73.7 ms
# 🪟 Rows 2701-2760 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.3 ms
# 🪟 Rows 2761-2820 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.7 ms
# 🪟 Rows 2821-2880 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 87.34 ms
# 🪟 Rows 2881-2940 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 80.48 ms
# 🪟 Rows 2941-3000 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 75.65 ms
# 🪟 Rows 3001-3060 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 72.15 ms
# 🪟 Rows 3061-3120 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 115.23 ms
# 🪟 Rows 3121-3180 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 74.3 ms
# 🪟 Rows 3181-3240 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 71.55 ms
# 🪟 Rows 3241-3300 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.56 ms
# 🪟 Rows 3301-3360 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 118.52 ms
# 🪟 Rows 3361-3420 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 74.0 ms
# 🪟 Rows 3421-3480 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 81.39 ms
# 🪟 Rows 3481-3540 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 73.06 ms
# 🪟 Rows 3541-3600 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 85.29 ms
# 🪟 Rows 3601-3660 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 80.1 ms
# 🪟 Rows 3661-3720 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 79.98 ms
# 🪟 Rows 3721-3780 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.54 ms
# 🪟 Rows 3781-3840 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.11 ms
# 🪟 Rows 3841-3900 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 71.39 ms
# 🪟 Rows 3901-3960 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 70.34 ms
# 🪟 Rows 3961-4020 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.16 ms
# 🪟 Rows 4021-4080 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 71.9 ms
# 🪟 Rows 4081-4140 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 86.31 ms
# 🪟 Rows 4141-4200 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.46 ms
# 🪟 Rows 4201-4260 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.87 ms
# 🪟 Rows 4261-4320 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 83.05 ms
# 🪟 Rows 4321-4380 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 84.68 ms
# 🪟 Rows 4381-4440 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.96 ms
# 🪟 Rows 4441-4500 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.6 ms
# 🪟 Rows 4501-4560 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.1 ms
# 🪟 Rows 4561-4620 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.95 ms
# 🪟 Rows 4621-4680 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 72.76 ms
# 🪟 Rows 4681-4740 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 73.5 ms
# 🪟 Rows 4741-4800 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.1 ms
# 🪟 Rows 4801-4860 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 73.54 ms
# 🪟 Rows 4861-4920 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 89.73 ms
# 🪟 Rows 4921-4980 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.79 ms
# 🪟 Rows 4981-5040 → Skipped (Label 0)
# 🪟 Rows 5041-5100 → Predicted: Stair Down (5) | Actual: Stair Up (6) ❌ | Latency: 82.02 ms
# 🪟 Rows 5101-5160 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 79.43 ms
# 🪟 Rows 5161-5220 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 79.62 ms
# 🪟 Rows 5221-5280 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 76.42 ms
# 🪟 Rows 5281-5340 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 74.98 ms
# 🪟 Rows 5341-5400 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 78.11 ms
# 🪟 Rows 5401-5460 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 72.64 ms
# 🪟 Rows 5461-5520 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 73.05 ms
# 🪟 Rows 5521-5580 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 78.18 ms
# 🪟 Rows 5581-5640 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 72.24 ms
# 🪟 Rows 5641-5700 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 75.09 ms
# 🪟 Rows 5701-5760 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 87.84 ms
# 🪟 Rows 5761-5820 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 84.25 ms
# 🪟 Rows 5821-5880 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 78.63 ms
# 🪟 Rows 5881-5940 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 80.68 ms
# 🪟 Rows 5941-6000 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 79.04 ms
# 🪟 Rows 6001-6060 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 78.2 ms
# 🪟 Rows 6061-6120 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 73.84 ms
# 🪟 Rows 6121-6180 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 76.1 ms
# 🪟 Rows 6181-6240 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 122.42 ms
# 🪟 Rows 6241-6300 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 77.63 ms
# 🪟 Rows 6301-6360 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 75.33 ms
# 🪟 Rows 6361-6420 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 75.12 ms
# 🪟 Rows 6421-6480 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 88.86 ms
# 🪟 Rows 6481-6540 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 84.03 ms
# 🪟 Rows 6541-6600 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 119.94 ms
# 🪟 Rows 6601-6660 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 88.92 ms
# 🪟 Rows 6661-6720 → Predicted: Running (2) | Actual: Stair Down (5) ❌ | Latency: 74.66 ms
# 🪟 Rows 6721-6780 → Skipped (Label 0)
# 🪟 Rows 6781-6840 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 79.14 ms
# 🪟 Rows 6841-6900 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 75.29 ms
# 🪟 Rows 6901-6960 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 80.35 ms
# 🪟 Rows 6961-7020 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 73.6 ms
# 🪟 Rows 7021-7080 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 74.91 ms
# 🪟 Rows 7081-7140 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 74.5 ms
# 🪟 Rows 7141-7200 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 78.5 ms
# 🪟 Rows 7201-7260 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 73.02 ms
# 🪟 Rows 7261-7320 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 93.92 ms
# 🪟 Rows 7321-7380 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 83.49 ms
# 🪟 Rows 7381-7440 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 89.5 ms
# 🪟 Rows 7441-7500 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 78.43 ms
# 🪟 Rows 7501-7560 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 78.63 ms
# 🪟 Rows 7561-7620 → Predicted: Stair Down (5) | Actual: Stair Up (6) ❌ | Latency: 77.96 ms
# 🪟 Rows 7621-7680 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 79.43 ms
# 🪟 Rows 7681-7740 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 76.48 ms
# 🪟 Rows 7741-7800 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 75.43 ms
# 🪟 Rows 7801-7860 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 146.29 ms
# 🪟 Rows 7861-7920 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 145.34 ms
# 🪟 Rows 7921-7980 → Predicted: Sitting (3) | Actual: Stair Down (5) ❌ | Latency: 170.26 ms
# 🪟 Rows 7981-8040 → Skipped (Label 0)
# 🪟 Rows 8041-8100 → Skipped (Label 0)
# 🪟 Rows 8101-8160 → Skipped (Label 0)
# 🪟 Rows 8161-8220 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 154.55 ms
# 🪟 Rows 8221-8280 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 144.08 ms
# 🪟 Rows 8281-8340 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 137.35 ms
# 🪟 Rows 8341-8400 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 142.54 ms
# 🪟 Rows 8401-8460 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 138.42 ms
#
# ⛔ Stopped by user.

# %% [markdown]
# #LSTM + 2D_CNN (Predict_LOG)

# %%
import os
import time
import numpy as np
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model


csv_file = "/content/drive/MyDrive/HAR Data & Models/sb_IMU.csv"
model_path = "/content/drive/MyDrive/HAR Data & Models/best_cnn2d_lstm_model.h5"
output_log = "LSTM_2d_CNN.csv"

window_size = 60
stride = 60
sampling_rate = 30
features = ['Acc_X', 'Acc_Y', 'Acc_Z', 'Gyro_X', 'Gyro_Y', 'Gyro_Z']
label_column = "Label"

categories = [1, 2, 3, 4, 5, 6]

def decode_activity(label):
    mapping = {
        1: "Walking",
        2: "Running",
        3: "Sitting",
        4: "Standing",
        5: "Stair Down",
        6: "Stair Up"
    }
    return mapping.get(label, "Unknown")


def normalize_segment(segment_array):
    """
    Normalize each feature (column) across the 60 timesteps.
    Keeps the shape (60, 6) for Conv1D.
    """
    scaler = StandardScaler()
    normalized = scaler.fit_transform(segment_array)  # shape (60, 6)
    return normalized


if not os.path.exists(output_log):
    with open(output_log, "w") as f:
        f.write("Timestamp,Actual_Label,Predicted_Label,Latency(ms),Valid\n")


model = load_model(model_path)

def live_predict():
    print("📡 Monitoring for new data in sliding windows...\nPress Ctrl+C to stop.\n")
    last_row_read = 0

    try:
        while True:
            if not os.path.exists(csv_file):
                print(f"Waiting for file {csv_file} to appear...")
                time.sleep(1)
                continue

            df = pd.read_csv(csv_file)

            # Ensure necessary columns exist
            if not all(col in df.columns for col in features + [label_column]):
                print("Missing required columns. Waiting...")
                time.sleep(1)
                continue

            total_rows = len(df)

            if total_rows >= window_size:
                while last_row_read + window_size <= total_rows:
                    window = df.iloc[last_row_read:last_row_read + window_size]
                    actual_labels = window[label_column].values

                    # Skip windows with all labels = 0
                    if np.all(actual_labels == 0):
                        print(f"🪟 Rows {last_row_read+1}-{last_row_read+window_size} → Skipped (Label 0)")
                        last_row_read += stride
                        continue
                    # Apply preprocessing
                    feature_chunk = window[features].values  # (60, 6)
                    norm_chunk = normalize_segment(feature_chunk)  # (60, 6)

                    # Model expects (1, 60, 6)
                    X_input = norm_chunk[np.newaxis, ...]

                    # Prediction
                    start_time = time.time()
                    prediction = model.predict(X_input, verbose=0)[0]
                    latency_ms = round((time.time() - start_time) * 1000, 2)

                    predicted_label = categories[np.argmax(prediction)]
                    decoded_pred = decode_activity(predicted_label)

                    # Actual label = majority vote in window
                    actual_labels = actual_labels[actual_labels != 0]
                    actual_label = np.bincount(actual_labels).argmax() if len(actual_labels) > 0 else 0
                    decoded_actual = decode_activity(actual_label)

                    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                    match = "✅" if predicted_label == actual_label else "❌"

                    print(f"🪟 Rows {last_row_read+1}-{last_row_read+window_size} → "
                          f"Predicted: {decoded_pred} ({predicted_label}) | "
                          f"Actual: {decoded_actual} ({actual_label}) {match} | "
                          f"Latency: {latency_ms} ms")

                    # Save log
                    with open(output_log, "a") as f:
                        f.write(f"{timestamp},{decoded_actual},{decoded_pred},{latency_ms},{int(predicted_label == actual_label)}\n")

                    last_row_read += stride

            time.sleep(1 / sampling_rate)

    except KeyboardInterrupt:
        print("\n⛔ Stopped by user.")

if __name__ == "__main__":
    live_predict()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📡 Monitoring for new data in sliding windows...
# Press Ctrl+C to stop.
#
# 🪟 Rows 1-60 → Skipped (Label 0)
# 🪟 Rows 61-120 → Skipped (Label 0)
# 🪟 Rows 121-180 → Skipped (Label 0)
# 🪟 Rows 181-240 → Skipped (Label 0)
# 🪟 Rows 241-300 → Skipped (Label 0)
# 🪟 Rows 301-360 → Skipped (Label 0)
# 🪟 Rows 361-420 → Skipped (Label 0)
# 🪟 Rows 421-480 → Skipped (Label 0)
# 🪟 Rows 481-540 → Skipped (Label 0)
# 🪟 Rows 541-600 → Skipped (Label 0)
# 🪟 Rows 601-660 → Skipped (Label 0)
# 🪟 Rows 661-720 → Skipped (Label 0)
# 🪟 Rows 721-780 → Skipped (Label 0)
# 🪟 Rows 781-840 → Skipped (Label 0)
# 🪟 Rows 841-900 → Skipped (Label 0)
# 🪟 Rows 901-960 → Skipped (Label 0)
# 🪟 Rows 961-1020 → Skipped (Label 0)
# 🪟 Rows 1021-1080 → Skipped (Label 0)
# 🪟 Rows 1081-1140 → Skipped (Label 0)
# 🪟 Rows 1141-1200 → Skipped (Label 0)
# 🪟 Rows 1201-1260 → Skipped (Label 0)
# 🪟 Rows 1261-1320 → Skipped (Label 0)
# 🪟 Rows 1321-1380 → Skipped (Label 0)
# 🪟 Rows 1381-1440 → Skipped (Label 0)
# 🪟 Rows 1441-1500 → Skipped (Label 0)
# 🪟 Rows 1501-1560 → Skipped (Label 0)
# 🪟 Rows 1561-1620 → Skipped (Label 0)
# 🪟 Rows 1621-1680 → Predicted: Stair Down (5) | Actual: Walking (1) ❌ | Latency: 328.98 ms
# 🪟 Rows 1681-1740 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 80.06 ms
# 🪟 Rows 1741-1800 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 121.65 ms
# 🪟 Rows 1801-1860 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 145.61 ms
# 🪟 Rows 1861-1920 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 151.78 ms
# 🪟 Rows 1921-1980 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 143.99 ms
# 🪟 Rows 1981-2040 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 145.2 ms
# 🪟 Rows 2041-2100 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 104.13 ms
# 🪟 Rows 2101-2160 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 80.83 ms
# 🪟 Rows 2161-2220 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 86.39 ms
# 🪟 Rows 2221-2280 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.53 ms
# 🪟 Rows 2281-2340 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 74.73 ms
# 🪟 Rows 2341-2400 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.64 ms
# 🪟 Rows 2401-2460 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.97 ms
# 🪟 Rows 2461-2520 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.28 ms
# 🪟 Rows 2521-2580 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 82.11 ms
# 🪟 Rows 2581-2640 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.99 ms
# 🪟 Rows 2641-2700 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.8 ms
# 🪟 Rows 2701-2760 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.08 ms
# 🪟 Rows 2761-2820 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 87.82 ms
# 🪟 Rows 2821-2880 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 73.56 ms
# 🪟 Rows 2881-2940 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 81.79 ms
# 🪟 Rows 2941-3000 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 73.28 ms
# 🪟 Rows 3001-3060 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 84.84 ms
# 🪟 Rows 3061-3120 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.06 ms
# 🪟 Rows 3121-3180 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.17 ms
# 🪟 Rows 3181-3240 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.73 ms
# 🪟 Rows 3241-3300 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 83.66 ms
# 🪟 Rows 3301-3360 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 115.65 ms
# 🪟 Rows 3361-3420 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 141.63 ms
# 🪟 Rows 3421-3480 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 158.63 ms
# 🪟 Rows 3481-3540 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 143.61 ms
# 🪟 Rows 3541-3600 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 109.34 ms
# 🪟 Rows 3601-3660 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 112.94 ms
# 🪟 Rows 3661-3720 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 101.16 ms
# 🪟 Rows 3721-3780 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 107.18 ms
# 🪟 Rows 3781-3840 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 140.75 ms
# 🪟 Rows 3841-3900 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 144.86 ms
# 🪟 Rows 3901-3960 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 116.11 ms
# 🪟 Rows 3961-4020 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 161.61 ms
# 🪟 Rows 4021-4080 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 139.39 ms
# 🪟 Rows 4081-4140 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 106.88 ms
# 🪟 Rows 4141-4200 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 134.8 ms
# 🪟 Rows 4201-4260 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 108.58 ms
# 🪟 Rows 4261-4320 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 106.41 ms
# 🪟 Rows 4321-4380 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 103.02 ms
# 🪟 Rows 4381-4440 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 103.72 ms
# 🪟 Rows 4441-4500 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 140.39 ms
# 🪟 Rows 4501-4560 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 135.22 ms
# 🪟 Rows 4561-4620 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 149.54 ms
# 🪟 Rows 4621-4680 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 140.8 ms
# 🪟 Rows 4681-4740 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 164.49 ms
# 🪟 Rows 4741-4800 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 114.21 ms
# 🪟 Rows 4801-4860 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 146.9 ms
# 🪟 Rows 4861-4920 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 83.46 ms
# 🪟 Rows 4921-4980 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 94.6 ms
# 🪟 Rows 4981-5040 → Skipped (Label 0)
# 🪟 Rows 5041-5100 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 92.04 ms
# 🪟 Rows 5101-5160 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 78.0 ms
# 🪟 Rows 5161-5220 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 80.5 ms
# 🪟 Rows 5221-5280 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 86.01 ms
# 🪟 Rows 5281-5340 → Predicted: Stair Down (5) | Actual: Stair Up (6) ❌ | Latency: 74.62 ms
# 🪟 Rows 5341-5400 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 78.68 ms
# 🪟 Rows 5401-5460 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 78.19 ms
# 🪟 Rows 5461-5520 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 122.1 ms
# 🪟 Rows 5521-5580 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 118.42 ms
# 🪟 Rows 5581-5640 → Predicted: Stair Down (5) | Actual: Stair Up (6) ❌ | Latency: 76.01 ms
# 🪟 Rows 5641-5700 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 91.61 ms
# 🪟 Rows 5701-5760 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 87.45 ms
# 🪟 Rows 5761-5820 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 74.64 ms
# 🪟 Rows 5821-5880 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 73.26 ms
# 🪟 Rows 5881-5940 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 83.32 ms
# 🪟 Rows 5941-6000 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 75.73 ms
# 🪟 Rows 6001-6060 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 73.55 ms
# 🪟 Rows 6061-6120 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 76.1 ms
# 🪟 Rows 6121-6180 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 76.62 ms
# 🪟 Rows 6181-6240 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 78.23 ms
# 🪟 Rows 6241-6300 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 77.42 ms
# 🪟 Rows 6301-6360 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 114.94 ms
# 🪟 Rows 6361-6420 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 82.92 ms
# 🪟 Rows 6421-6480 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 93.11 ms
# 🪟 Rows 6481-6540 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 77.13 ms
# 🪟 Rows 6541-6600 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 85.46 ms
# 🪟 Rows 6601-6660 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 78.96 ms
# 🪟 Rows 6661-6720 → Predicted: Standing (4) | Actual: Stair Down (5) ❌ | Latency: 79.88 ms
# 🪟 Rows 6721-6780 → Skipped (Label 0)
# 🪟 Rows 6781-6840 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 79.41 ms
# 🪟 Rows 6841-6900 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 75.93 ms
# 🪟 Rows 6901-6960 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 74.81 ms
# 🪟 Rows 6961-7020 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 84.06 ms
# 🪟 Rows 7021-7080 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 75.25 ms
# 🪟 Rows 7081-7140 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 77.69 ms
# 🪟 Rows 7141-7200 → Predicted: Stair Down (5) | Actual: Stair Up (6) ❌ | Latency: 77.58 ms
# 🪟 Rows 7201-7260 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 115.02 ms
# 🪟 Rows 7261-7320 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 72.92 ms
# 🪟 Rows 7321-7380 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 84.57 ms
# 🪟 Rows 7381-7440 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 75.46 ms
# 🪟 Rows 7441-7500 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 74.55 ms
# 🪟 Rows 7501-7560 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 71.94 ms
# 🪟 Rows 7561-7620 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 75.81 ms
# 🪟 Rows 7621-7680 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 77.36 ms
# 🪟 Rows 7681-7740 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 87.18 ms
#
# ⛔ Stopped by user.

# %% [markdown]
# #2D CNN(Predict Log)

# %%
import os
import time
import numpy as np
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model


csv_file = "/content/drive/MyDrive/HAR Data & Models/sb_IMU.csv"
model_path = "/content/drive/MyDrive/HAR Data & Models/best_2dcnn_model.h5"
output_log = "2d_CNN.csv"

window_size = 60
stride = 60
sampling_rate = 30
features = ['Acc_X', 'Acc_Y', 'Acc_Z', 'Gyro_X', 'Gyro_Y', 'Gyro_Z']
label_column = "Label"

categories = [1, 2, 3, 4, 5, 6]

def decode_activity(label):
    mapping = {
        1: "Walking",
        2: "Running",
        3: "Sitting",
        4: "Standing",
        5: "Stair Down",
        6: "Stair Up"
    }
    return mapping.get(label, "Unknown")


def normalize_segment(segment_array):
    """
    Normalize each feature (column) across the 60 timesteps.
    Keeps the shape (60, 6) for Conv1D.
    """
    scaler = StandardScaler()
    normalized = scaler.fit_transform(segment_array)  # shape (60, 6)
    return normalized


if not os.path.exists(output_log):
    with open(output_log, "w") as f:
        f.write("Timestamp,Actual_Label,Predicted_Label,Latency(ms),Valid\n")


model = load_model(model_path)

def live_predict():
    print("📡 Monitoring for new data in sliding windows...\nPress Ctrl+C to stop.\n")
    last_row_read = 0

    try:
        while True:
            if not os.path.exists(csv_file):
                print(f"Waiting for file {csv_file} to appear...")
                time.sleep(1)
                continue

            df = pd.read_csv(csv_file)

            # Ensure necessary columns exist
            if not all(col in df.columns for col in features + [label_column]):
                print("Missing required columns. Waiting...")
                time.sleep(1)
                continue

            total_rows = len(df)

            if total_rows >= window_size:
                while last_row_read + window_size <= total_rows:
                    window = df.iloc[last_row_read:last_row_read + window_size]
                    actual_labels = window[label_column].values

                    # Skip windows with all labels = 0
                    if np.all(actual_labels == 0):
                        print(f"🪟 Rows {last_row_read+1}-{last_row_read+window_size} → Skipped (Label 0)")
                        last_row_read += stride
                        continue
                    # Apply preprocessing
                    feature_chunk = window[features].values  # (60, 6)
                    norm_chunk = normalize_segment(feature_chunk)  # (60, 6)

                    # Model expects (1, 60, 6)
                    X_input = norm_chunk[np.newaxis, ...]

                    # Prediction
                    start_time = time.time()
                    prediction = model.predict(X_input, verbose=0)[0]
                    latency_ms = round((time.time() - start_time) * 1000, 2)

                    predicted_label = categories[np.argmax(prediction)]
                    decoded_pred = decode_activity(predicted_label)

                    # Actual label = majority vote in window
                    actual_labels = actual_labels[actual_labels != 0]
                    actual_label = np.bincount(actual_labels).argmax() if len(actual_labels) > 0 else 0
                    decoded_actual = decode_activity(actual_label)

                    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                    match = "✅" if predicted_label == actual_label else "❌"

                    print(f"🪟 Rows {last_row_read+1}-{last_row_read+window_size} → "
                          f"Predicted: {decoded_pred} ({predicted_label}) | "
                          f"Actual: {decoded_actual} ({actual_label}) {match} | "
                          f"Latency: {latency_ms} ms")

                    # Save log
                    with open(output_log, "a") as f:
                        f.write(f"{timestamp},{decoded_actual},{decoded_pred},{latency_ms},{int(predicted_label == actual_label)}\n")

                    last_row_read += stride

            time.sleep(1 / sampling_rate)

    except KeyboardInterrupt:
        print("\n⛔ Stopped by user.")

if __name__ == "__main__":
    live_predict()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📡 Monitoring for new data in sliding windows...
# Press Ctrl+C to stop.
#
# 🪟 Rows 1-60 → Skipped (Label 0)
# 🪟 Rows 61-120 → Skipped (Label 0)
# 🪟 Rows 121-180 → Skipped (Label 0)
# 🪟 Rows 181-240 → Skipped (Label 0)
# 🪟 Rows 241-300 → Skipped (Label 0)
# 🪟 Rows 301-360 → Skipped (Label 0)
# 🪟 Rows 361-420 → Skipped (Label 0)
# 🪟 Rows 421-480 → Skipped (Label 0)
# 🪟 Rows 481-540 → Skipped (Label 0)
# 🪟 Rows 541-600 → Skipped (Label 0)
# 🪟 Rows 601-660 → Skipped (Label 0)
# 🪟 Rows 661-720 → Skipped (Label 0)
# 🪟 Rows 721-780 → Skipped (Label 0)
# 🪟 Rows 781-840 → Skipped (Label 0)
# 🪟 Rows 841-900 → Skipped (Label 0)
# 🪟 Rows 901-960 → Skipped (Label 0)
# 🪟 Rows 961-1020 → Skipped (Label 0)
# 🪟 Rows 1021-1080 → Skipped (Label 0)
# 🪟 Rows 1081-1140 → Skipped (Label 0)
# 🪟 Rows 1141-1200 → Skipped (Label 0)
# 🪟 Rows 1201-1260 → Skipped (Label 0)
# 🪟 Rows 1261-1320 → Skipped (Label 0)
# 🪟 Rows 1321-1380 → Skipped (Label 0)
# 🪟 Rows 1381-1440 → Skipped (Label 0)
# 🪟 Rows 1441-1500 → Skipped (Label 0)
# 🪟 Rows 1501-1560 → Skipped (Label 0)
# 🪟 Rows 1561-1620 → Skipped (Label 0)
# 🪟 Rows 1621-1680 → Predicted: Sitting (3) | Actual: Walking (1) ❌ | Latency: 139.62 ms
# 🪟 Rows 1681-1740 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 116.75 ms
# 🪟 Rows 1741-1800 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 82.87 ms
# 🪟 Rows 1801-1860 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 133.9 ms
# 🪟 Rows 1861-1920 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.41 ms
# 🪟 Rows 1921-1980 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 84.94 ms
# 🪟 Rows 1981-2040 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 78.16 ms
# 🪟 Rows 2041-2100 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 119.4 ms
# 🪟 Rows 2101-2160 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 86.65 ms
# 🪟 Rows 2161-2220 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.49 ms
# 🪟 Rows 2221-2280 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 74.62 ms
# 🪟 Rows 2281-2340 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 116.06 ms
# 🪟 Rows 2341-2400 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 85.5 ms
# 🪟 Rows 2401-2460 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.73 ms
# 🪟 Rows 2461-2520 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 91.01 ms
# 🪟 Rows 2521-2580 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 78.22 ms
# 🪟 Rows 2581-2640 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.04 ms
# 🪟 Rows 2641-2700 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.15 ms
# 🪟 Rows 2701-2760 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 73.9 ms
# 🪟 Rows 2761-2820 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.96 ms
# 🪟 Rows 2821-2880 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 122.16 ms
# 🪟 Rows 2881-2940 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.48 ms
# 🪟 Rows 2941-3000 → Predicted: Stair Down (5) | Actual: Walking (1) ❌ | Latency: 78.98 ms
# 🪟 Rows 3001-3060 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 82.83 ms
# 🪟 Rows 3061-3120 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 83.28 ms
# 🪟 Rows 3121-3180 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 86.54 ms
# 🪟 Rows 3181-3240 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 95.93 ms
# 🪟 Rows 3241-3300 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 118.35 ms
# 🪟 Rows 3301-3360 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.52 ms
# 🪟 Rows 3361-3420 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 79.57 ms
# 🪟 Rows 3421-3480 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 119.16 ms
# 🪟 Rows 3481-3540 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.62 ms
# 🪟 Rows 3541-3600 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.67 ms
# 🪟 Rows 3601-3660 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.22 ms
# 🪟 Rows 3661-3720 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.23 ms
# 🪟 Rows 3721-3780 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.63 ms
# 🪟 Rows 3781-3840 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.42 ms
# 🪟 Rows 3841-3900 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 117.42 ms
# 🪟 Rows 3901-3960 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 81.41 ms
# 🪟 Rows 3961-4020 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 74.73 ms
# 🪟 Rows 4021-4080 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 113.23 ms
# 🪟 Rows 4081-4140 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 80.58 ms
# 🪟 Rows 4141-4200 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.58 ms
# 🪟 Rows 4201-4260 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 72.6 ms
# 🪟 Rows 4261-4320 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 82.78 ms
# 🪟 Rows 4321-4380 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 74.95 ms
# 🪟 Rows 4381-4440 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.36 ms
# 🪟 Rows 4441-4500 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.72 ms
# 🪟 Rows 4501-4560 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 126.75 ms
# 🪟 Rows 4561-4620 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 133.6 ms
# 🪟 Rows 4621-4680 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.77 ms
# 🪟 Rows 4681-4740 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 131.78 ms
# 🪟 Rows 4741-4800 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 148.76 ms
# 🪟 Rows 4801-4860 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 139.39 ms
# 🪟 Rows 4861-4920 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 107.03 ms
# 🪟 Rows 4921-4980 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 141.48 ms
# 🪟 Rows 4981-5040 → Skipped (Label 0)
# 🪟 Rows 5041-5100 → Predicted: Sitting (3) | Actual: Stair Up (6) ❌ | Latency: 101.5 ms
# 🪟 Rows 5101-5160 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 136.96 ms
# 🪟 Rows 5161-5220 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 147.18 ms
# 🪟 Rows 5221-5280 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 148.34 ms
# 🪟 Rows 5281-5340 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 119.13 ms
# 🪟 Rows 5341-5400 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 115.9 ms
# 🪟 Rows 5401-5460 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 109.76 ms
# 🪟 Rows 5461-5520 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 112.51 ms
# 🪟 Rows 5521-5580 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 141.42 ms
# 🪟 Rows 5581-5640 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 139.77 ms
# 🪟 Rows 5641-5700 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 137.85 ms
# 🪟 Rows 5701-5760 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 105.35 ms
# 🪟 Rows 5761-5820 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 137.83 ms
# 🪟 Rows 5821-5880 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 109.17 ms
# 🪟 Rows 5881-5940 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 137.2 ms
# 🪟 Rows 5941-6000 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 153.02 ms
# 🪟 Rows 6001-6060 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 126.36 ms
# 🪟 Rows 6061-6120 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 152.54 ms
# 🪟 Rows 6121-6180 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 144.15 ms
# 🪟 Rows 6181-6240 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 145.93 ms
# 🪟 Rows 6241-6300 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 78.14 ms
# 🪟 Rows 6301-6360 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 78.62 ms
# 🪟 Rows 6361-6420 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 78.78 ms
# 🪟 Rows 6421-6480 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 74.05 ms
# 🪟 Rows 6481-6540 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 75.17 ms
# 🪟 Rows 6541-6600 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 77.43 ms
# 🪟 Rows 6601-6660 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 116.1 ms
# 🪟 Rows 6661-6720 → Predicted: Sitting (3) | Actual: Stair Down (5) ❌ | Latency: 75.33 ms
# 🪟 Rows 6721-6780 → Skipped (Label 0)
# 🪟 Rows 6781-6840 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 141.28 ms
# 🪟 Rows 6841-6900 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 84.03 ms
# 🪟 Rows 6901-6960 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 76.89 ms
# 🪟 Rows 6961-7020 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 122.93 ms
# 🪟 Rows 7021-7080 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 118.93 ms
# 🪟 Rows 7081-7140 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 76.86 ms
# 🪟 Rows 7141-7200 → Predicted: Sitting (3) | Actual: Stair Up (6) ❌ | Latency: 78.74 ms
# 🪟 Rows 7201-7260 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 84.58 ms
# 🪟 Rows 7261-7320 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 117.6 ms
# 🪟 Rows 7321-7380 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 74.47 ms
# 🪟 Rows 7381-7440 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 115.88 ms
# 🪟 Rows 7441-7500 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 81.25 ms
# 🪟 Rows 7501-7560 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 80.4 ms
# 🪟 Rows 7561-7620 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 125.21 ms
# 🪟 Rows 7621-7680 → Predicted: Walking (1) | Actual: Stair Down (5) ❌ | Latency: 82.33 ms
# 🪟 Rows 7681-7740 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 78.4 ms
# 🪟 Rows 7741-7800 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 120.23 ms
# 🪟 Rows 7801-7860 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 74.62 ms
# 🪟 Rows 7861-7920 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 74.27 ms
# 🪟 Rows 7921-7980 → Predicted: Sitting (3) | Actual: Stair Down (5) ❌ | Latency: 80.46 ms
# 🪟 Rows 7981-8040 → Skipped (Label 0)
# 🪟 Rows 8041-8100 → Skipped (Label 0)
# 🪟 Rows 8101-8160 → Skipped (Label 0)
# 🪟 Rows 8161-8220 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 75.38 ms
# 🪟 Rows 8221-8280 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 119.05 ms
# 🪟 Rows 8281-8340 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 81.17 ms
# 🪟 Rows 8341-8400 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 70.63 ms
# 🪟 Rows 8401-8460 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 80.51 ms
# 🪟 Rows 8461-8520 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 124.31 ms
# 🪟 Rows 8521-8580 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 77.12 ms
# 🪟 Rows 8581-8640 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 78.1 ms
# 🪟 Rows 8641-8700 → Predicted: Walking (1) | Actual: Stair Down (5) ❌ | Latency: 119.35 ms
# 🪟 Rows 8701-8760 → Skipped (Label 0)
# 🪟 Rows 8761-8820 → Skipped (Label 0)
# 🪟 Rows 8821-8880 → Skipped (Label 0)
# 🪟 Rows 8881-8940 → Skipped (Label 0)
# 🪟 Rows 8941-9000 → Predicted: Stair Up (6) | Actual: Running (2) ❌ | Latency: 74.55 ms
# 🪟 Rows 9001-9060 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 76.76 ms
# 🪟 Rows 9061-9120 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 121.84 ms
# 🪟 Rows 9121-9180 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 117.3 ms
# 🪟 Rows 9181-9240 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 78.55 ms
# 🪟 Rows 9241-9300 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 119.44 ms
# 🪟 Rows 9301-9360 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 89.7 ms
# 🪟 Rows 9361-9420 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 126.14 ms
# 🪟 Rows 9421-9480 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 81.93 ms
# 🪟 Rows 9481-9540 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 77.26 ms
# 🪟 Rows 9541-9600 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 78.63 ms
# 🪟 Rows 9601-9660 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 79.39 ms
# 🪟 Rows 9661-9720 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 78.93 ms
# 🪟 Rows 9721-9780 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 79.75 ms
# 🪟 Rows 9781-9840 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 117.59 ms
# 🪟 Rows 9841-9900 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 75.31 ms
# 🪟 Rows 9901-9960 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 118.14 ms
# 🪟 Rows 9961-10020 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 79.71 ms
# 🪟 Rows 10021-10080 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 74.62 ms
# 🪟 Rows 10081-10140 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 89.75 ms
# 🪟 Rows 10141-10200 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 78.8 ms
# 🪟 Rows 10201-10260 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 79.6 ms
# 🪟 Rows 10261-10320 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 84.14 ms
# 🪟 Rows 10321-10380 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 80.11 ms
# 🪟 Rows 10381-10440 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 81.69 ms
# 🪟 Rows 10441-10500 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 88.9 ms
# 🪟 Rows 10501-10560 → Skipped (Label 0)
# 🪟 Rows 10561-10620 → Predicted: Stair Down (5) | Actual: Running (2) ❌ | Latency: 95.11 ms
# 🪟 Rows 10621-10680 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 78.07 ms
# 🪟 Rows 10681-10740 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 80.27 ms
# 🪟 Rows 10741-10800 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 77.75 ms
# 🪟 Rows 10801-10860 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 76.87 ms
# 🪟 Rows 10861-10920 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 91.5 ms
# 🪟 Rows 10921-10980 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 77.13 ms
# 🪟 Rows 10981-11040 → Predicted: Sitting (3) | Actual: Running (2) ❌ | Latency: 77.78 ms
# 🪟 Rows 11041-11100 → Skipped (Label 0)
# 🪟 Rows 11101-11160 → Skipped (Label 0)
# 🪟 Rows 11161-11220 → Skipped (Label 0)
# 🪟 Rows 11221-11280 → Skipped (Label 0)
# 🪟 Rows 11281-11340 → Skipped (Label 0)
# 🪟 Rows 11341-11400 → Skipped (Label 0)
# 🪟 Rows 11401-11460 → Skipped (Label 0)
# 🪟 Rows 11461-11520 → Skipped (Label 0)
# 🪟 Rows 11521-11580 → Skipped (Label 0)
# 🪟 Rows 11581-11640 → Skipped (Label 0)
# 🪟 Rows 11641-11700 → Skipped (Label 0)
# 🪟 Rows 11701-11760 → Skipped (Label 0)
# 🪟 Rows 11761-11820 → Skipped (Label 0)
# 🪟 Rows 11821-11880 → Skipped (Label 0)
# 🪟 Rows 11881-11940 → Skipped (Label 0)
# 🪟 Rows 11941-12000 → Skipped (Label 0)
# 🪟 Rows 12001-12060 → Skipped (Label 0)
# 🪟 Rows 12061-12120 → Skipped (Label 0)
# 🪟 Rows 12121-12180 → Skipped (Label 0)
# 🪟 Rows 12181-12240 → Skipped (Label 0)
# 🪟 Rows 12241-12300 → Skipped (Label 0)
# 🪟 Rows 12301-12360 → Skipped (Label 0)
# 🪟 Rows 12361-12420 → Skipped (Label 0)
# 🪟 Rows 12421-12480 → Skipped (Label 0)
# 🪟 Rows 12481-12540 → Skipped (Label 0)
# 🪟 Rows 12541-12600 → Skipped (Label 0)
# 🪟 Rows 12601-12660 → Skipped (Label 0)
# 🪟 Rows 12661-12720 → Skipped (Label 0)
# 🪟 Rows 12721-12780 → Skipped (Label 0)
# 🪟 Rows 12781-12840 → Skipped (Label 0)
# 🪟 Rows 12841-12900 → Skipped (Label 0)
# 🪟 Rows 12901-12960 → Skipped (Label 0)
# 🪟 Rows 12961-13020 → Skipped (Label 0)
# 🪟 Rows 13021-13080 → Skipped (Label 0)
# 🪟 Rows 13081-13140 → Skipped (Label 0)
# 🪟 Rows 13141-13200 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 84.27 ms
# 🪟 Rows 13201-13260 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 78.43 ms
# 🪟 Rows 13261-13320 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 78.94 ms
# 🪟 Rows 13321-13380 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 132.64 ms
# 🪟 Rows 13381-13440 → Predicted: Standing (4) | Actual: Sitting (3) ❌ | Latency: 88.8 ms
# 🪟 Rows 13441-13500 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 75.94 ms
# 🪟 Rows 13501-13560 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 118.57 ms
# 🪟 Rows 13561-13620 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 78.98 ms
# 🪟 Rows 13621-13680 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 73.34 ms
# 🪟 Rows 13681-13740 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 124.22 ms
# 🪟 Rows 13741-13800 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 81.09 ms
# 🪟 Rows 13801-13860 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 83.98 ms
# 🪟 Rows 13861-13920 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 87.39 ms
# 🪟 Rows 13921-13980 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 75.85 ms
# 🪟 Rows 13981-14040 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 82.64 ms
# 🪟 Rows 14041-14100 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 128.82 ms
# 🪟 Rows 14101-14160 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 76.54 ms
# 🪟 Rows 14161-14220 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 78.14 ms
# 🪟 Rows 14221-14280 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 121.37 ms
# 🪟 Rows 14281-14340 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 74.75 ms
# 🪟 Rows 14341-14400 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 74.48 ms
# 🪟 Rows 14401-14460 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 89.43 ms
# 🪟 Rows 14461-14520 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 79.54 ms
# 🪟 Rows 14521-14580 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 77.58 ms
# 🪟 Rows 14581-14640 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 83.19 ms
# 🪟 Rows 14641-14700 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 87.33 ms
# 🪟 Rows 14701-14760 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 78.34 ms
# 🪟 Rows 14761-14820 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 93.66 ms
# 🪟 Rows 14821-14880 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 77.83 ms
# 🪟 Rows 14881-14940 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 79.2 ms
# 🪟 Rows 14941-15000 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 76.28 ms
# 🪟 Rows 15001-15060 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 72.18 ms
# 🪟 Rows 15061-15120 → Predicted: Stair Up (6) | Actual: Sitting (3) ❌ | Latency: 74.32 ms
# 🪟 Rows 15121-15180 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 85.04 ms
# 🪟 Rows 15181-15240 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 80.6 ms
# 🪟 Rows 15241-15300 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 116.86 ms
# 🪟 Rows 15301-15360 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 79.92 ms
# 🪟 Rows 15361-15420 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 77.32 ms
# 🪟 Rows 15421-15480 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 128.75 ms
# 🪟 Rows 15481-15540 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 175.71 ms
# 🪟 Rows 15541-15600 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 110.26 ms
# 🪟 Rows 15601-15660 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 141.35 ms
# 🪟 Rows 15661-15720 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 138.39 ms
# 🪟 Rows 15721-15780 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 139.25 ms
# 🪟 Rows 15781-15840 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 148.32 ms
# 🪟 Rows 15841-15900 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 157.78 ms
# 🪟 Rows 15901-15960 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 158.85 ms
# 🪟 Rows 15961-16020 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 145.1 ms
# 🪟 Rows 16021-16080 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 145.38 ms
# 🪟 Rows 16081-16140 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 141.23 ms
# 🪟 Rows 16141-16200 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 148.46 ms
# 🪟 Rows 16201-16260 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 142.02 ms
# 🪟 Rows 16261-16320 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 147.0 ms
# 🪟 Rows 16321-16380 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 148.21 ms
# 🪟 Rows 16381-16440 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 142.82 ms
# 🪟 Rows 16441-16500 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 144.61 ms
# 🪟 Rows 16501-16560 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 115.3 ms
# 🪟 Rows 16561-16620 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 166.65 ms
# 🪟 Rows 16621-16680 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 151.63 ms
# 🪟 Rows 16681-16740 → Predicted: Sitting (3) | Actual: Standing (4) ❌ | Latency: 146.99 ms
# 🪟 Rows 16741-16800 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 81.04 ms
# 🪟 Rows 16801-16860 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 95.62 ms
# 🪟 Rows 16861-16920 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 72.56 ms
# 🪟 Rows 16921-16980 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 79.47 ms
# 🪟 Rows 16981-17040 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 77.31 ms
# 🪟 Rows 17041-17100 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 79.55 ms
# 🪟 Rows 17101-17160 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 75.36 ms
# 🪟 Rows 17161-17220 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 76.61 ms
# 🪟 Rows 17221-17280 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 73.67 ms
# 🪟 Rows 17281-17340 → Skipped (Label 0)
# 🪟 Rows 17341-17400 → Skipped (Label 0)
# 🪟 Rows 17401-17460 → Skipped (Label 0)
# 🪟 Rows 17461-17520 → Skipped (Label 0)
# 🪟 Rows 17521-17580 → Skipped (Label 0)
# 🪟 Rows 17581-17640 → Skipped (Label 0)
# 🪟 Rows 17641-17700 → Skipped (Label 0)
# 🪟 Rows 17701-17760 → Skipped (Label 0)
# 🪟 Rows 17761-17820 → Skipped (Label 0)
# 🪟 Rows 17821-17880 → Skipped (Label 0)
# 🪟 Rows 17881-17940 → Skipped (Label 0)
# 🪟 Rows 17941-18000 → Skipped (Label 0)
# 🪟 Rows 18001-18060 → Skipped (Label 0)
# 🪟 Rows 18061-18120 → Skipped (Label 0)
# 🪟 Rows 18121-18180 → Skipped (Label 0)
# 🪟 Rows 18181-18240 → Skipped (Label 0)
# 🪟 Rows 18241-18300 → Skipped (Label 0)
# 🪟 Rows 18301-18360 → Skipped (Label 0)
# 🪟 Rows 18361-18420 → Skipped (Label 0)
# 🪟 Rows 18421-18480 → Skipped (Label 0)
# 🪟 Rows 18481-18540 → Skipped (Label 0)
# 🪟 Rows 18541-18600 → Skipped (Label 0)
# 🪟 Rows 18601-18660 → Skipped (Label 0)
# 🪟 Rows 18661-18720 → Skipped (Label 0)
# 🪟 Rows 18721-18780 → Skipped (Label 0)
# 🪟 Rows 18781-18840 → Skipped (Label 0)
# 🪟 Rows 18841-18900 → Skipped (Label 0)
# 🪟 Rows 18901-18960 → Predicted: Standing (4) | Actual: Sitting (3) ❌ | Latency: 85.64 ms
# 🪟 Rows 18961-19020 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 78.11 ms
# 🪟 Rows 19021-19080 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 120.68 ms
# 🪟 Rows 19081-19140 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 83.13 ms
# 🪟 Rows 19141-19200 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 92.44 ms
# 🪟 Rows 19201-19260 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 79.23 ms
# 🪟 Rows 19261-19320 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 75.06 ms
# 🪟 Rows 19321-19380 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 119.89 ms
# 🪟 Rows 19381-19440 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 77.03 ms
# 🪟 Rows 19441-19500 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 115.77 ms
# 🪟 Rows 19501-19560 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 76.92 ms
# 🪟 Rows 19561-19620 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 79.59 ms
# 🪟 Rows 19621-19680 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 84.3 ms
# 🪟 Rows 19681-19740 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 79.11 ms
# 🪟 Rows 19741-19800 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 87.3 ms
# 🪟 Rows 19801-19860 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 81.26 ms
# 🪟 Rows 19861-19920 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 91.19 ms
# 🪟 Rows 19921-19980 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 81.25 ms
# 🪟 Rows 19981-20040 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 118.06 ms
# 🪟 Rows 20041-20100 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 78.36 ms
# 🪟 Rows 20101-20160 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 80.84 ms
# 🪟 Rows 20161-20220 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 121.63 ms
# 🪟 Rows 20221-20280 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 73.68 ms
# 🪟 Rows 20281-20340 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 73.76 ms
# 🪟 Rows 20341-20400 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 86.79 ms
# 🪟 Rows 20401-20460 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 83.14 ms
# 🪟 Rows 20461-20520 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 118.09 ms
# 🪟 Rows 20521-20580 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 95.16 ms
# 🪟 Rows 20581-20640 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 81.91 ms
# 🪟 Rows 20641-20700 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 80.61 ms
# 🪟 Rows 20701-20760 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 74.86 ms
# 🪟 Rows 20761-20820 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 77.7 ms
# 🪟 Rows 20821-20880 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 120.99 ms
# 🪟 Rows 20881-20940 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 74.61 ms
# 🪟 Rows 20941-21000 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 77.23 ms
# 🪟 Rows 21001-21060 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 79.02 ms
# 🪟 Rows 21061-21120 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 93.7 ms
# 🪟 Rows 21121-21180 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 77.59 ms
# 🪟 Rows 21181-21240 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 84.52 ms
# 🪟 Rows 21241-21300 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 134.88 ms
# 🪟 Rows 21301-21360 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 79.8 ms
# 🪟 Rows 21361-21420 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 80.11 ms
# 🪟 Rows 21421-21480 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 81.3 ms
# 🪟 Rows 21481-21540 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 80.8 ms
# 🪟 Rows 21541-21600 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 74.57 ms
# 🪟 Rows 21601-21660 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 75.37 ms
# 🪟 Rows 21661-21720 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 122.36 ms
# 🪟 Rows 21721-21780 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 75.92 ms
# 🪟 Rows 21781-21840 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 83.74 ms
# 🪟 Rows 21841-21900 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 123.0 ms
# 🪟 Rows 21901-21960 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 92.86 ms
# 🪟 Rows 21961-22020 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 79.97 ms
# 🪟 Rows 22021-22080 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 89.65 ms
# 🪟 Rows 22081-22140 → Predicted: Sitting (3) | Actual: Standing (4) ❌ | Latency: 81.17 ms
# 🪟 Rows 22141-22200 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 76.4 ms
# 🪟 Rows 22201-22260 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 78.23 ms
# 🪟 Rows 22261-22320 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 78.71 ms
# 🪟 Rows 22321-22380 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 79.18 ms
# 🪟 Rows 22381-22440 → Predicted: Standing (4) | Actual: Walking (1) ❌ | Latency: 79.24 ms
# 🪟 Rows 22441-22500 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 74.21 ms
# 🪟 Rows 22501-22560 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 87.94 ms
# 🪟 Rows 22561-22620 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 86.52 ms
# 🪟 Rows 22621-22680 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 98.52 ms
# 🪟 Rows 22681-22740 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 118.9 ms
# 🪟 Rows 22741-22800 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 80.02 ms
# 🪟 Rows 22801-22860 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.78 ms
# 🪟 Rows 22861-22920 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.38 ms
# 🪟 Rows 22921-22980 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.55 ms
# 🪟 Rows 22981-23040 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.93 ms
# 🪟 Rows 23041-23100 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.97 ms
# 🪟 Rows 23101-23160 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 72.23 ms
# 🪟 Rows 23161-23220 → Predicted: Standing (4) | Actual: Stair Down (5) ❌ | Latency: 74.05 ms
# 🪟 Rows 23221-23280 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 127.32 ms
# 🪟 Rows 23281-23340 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 76.76 ms
# 🪟 Rows 23341-23400 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 132.36 ms
# 🪟 Rows 23401-23460 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 122.44 ms
# 🪟 Rows 23461-23520 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 91.55 ms
# 🪟 Rows 23521-23580 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 79.59 ms
# 🪟 Rows 23581-23640 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 83.18 ms
# 🪟 Rows 23641-23700 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 85.5 ms
# 🪟 Rows 23701-23760 → Predicted: Standing (4) | Actual: Stair Down (5) ❌ | Latency: 83.02 ms
# 🪟 Rows 23761-23820 → Skipped (Label 0)
# 🪟 Rows 23821-23880 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 77.56 ms
# 🪟 Rows 23881-23940 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 81.78 ms
# 🪟 Rows 23941-24000 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 74.23 ms
# 🪟 Rows 24001-24060 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 86.01 ms
# 🪟 Rows 24061-24120 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 102.94 ms
# 🪟 Rows 24121-24180 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 79.0 ms
# 🪟 Rows 24181-24240 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 120.73 ms
# 🪟 Rows 24241-24300 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 117.53 ms
# 🪟 Rows 24301-24360 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 78.61 ms
# 🪟 Rows 24361-24420 → Predicted: Stair Up (6) | Actual: Walking (1) ❌ | Latency: 75.99 ms
# 🪟 Rows 24421-24480 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 118.84 ms
# 🪟 Rows 24481-24540 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 76.88 ms
# 🪟 Rows 24541-24600 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 73.96 ms
# 🪟 Rows 24601-24660 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 75.23 ms
# 🪟 Rows 24661-24720 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 79.01 ms
# 🪟 Rows 24721-24780 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 100.9 ms
# 🪟 Rows 24781-24840 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 120.46 ms
# 🪟 Rows 24841-24900 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 84.88 ms
# 🪟 Rows 24901-24960 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.72 ms
# 🪟 Rows 24961-25020 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 122.28 ms
# 🪟 Rows 25021-25080 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 124.35 ms
# 🪟 Rows 25081-25140 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 126.05 ms
# 🪟 Rows 25141-25200 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 140.31 ms
# 🪟 Rows 25201-25260 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 112.93 ms
# 🪟 Rows 25261-25320 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 147.89 ms
# 🪟 Rows 25321-25380 → Predicted: Standing (4) | Actual: Walking (1) ❌ | Latency: 141.77 ms
# 🪟 Rows 25381-25440 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 135.21 ms
# 🪟 Rows 25441-25500 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 158.68 ms
# 🪟 Rows 25501-25560 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 146.05 ms
# 🪟 Rows 25561-25620 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 120.91 ms
# 🪟 Rows 25621-25680 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 151.18 ms
# 🪟 Rows 25681-25740 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 152.4 ms
# 🪟 Rows 25741-25800 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 153.0 ms
# 🪟 Rows 25801-25860 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 146.58 ms
# 🪟 Rows 25861-25920 → Predicted: Standing (4) | Actual: Stair Up (6) ❌ | Latency: 110.74 ms
# 🪟 Rows 25921-25980 → Predicted: Standing (4) | Actual: Stair Up (6) ❌ | Latency: 103.04 ms
# 🪟 Rows 25981-26040 → Skipped (Label 0)
# 🪟 Rows 26041-26100 → Skipped (Label 0)
# 🪟 Rows 26101-26160 → Skipped (Label 0)
# 🪟 Rows 26161-26220 → Skipped (Label 0)
# 🪟 Rows 26221-26280 → Skipped (Label 0)
# 🪟 Rows 26281-26340 → Skipped (Label 0)
# 🪟 Rows 26341-26400 → Skipped (Label 0)
# 🪟 Rows 26401-26460 → Skipped (Label 0)
# 🪟 Rows 26461-26520 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 133.76 ms
# 🪟 Rows 26521-26580 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 140.06 ms
# 🪟 Rows 26581-26640 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 144.74 ms
# 🪟 Rows 26641-26700 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 160.08 ms
# 🪟 Rows 26701-26760 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 131.15 ms
# 🪟 Rows 26761-26820 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 152.76 ms
# 🪟 Rows 26821-26880 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 150.24 ms
# 🪟 Rows 26881-26940 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 142.09 ms
# 🪟 Rows 26941-27000 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 82.16 ms
# 🪟 Rows 27001-27060 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 125.79 ms
# 🪟 Rows 27061-27120 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 124.57 ms
# 🪟 Rows 27121-27180 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 88.31 ms
# 🪟 Rows 27181-27240 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 86.01 ms
# 🪟 Rows 27241-27300 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 80.37 ms
# 🪟 Rows 27301-27360 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 79.31 ms
# 🪟 Rows 27361-27420 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 82.75 ms
# 🪟 Rows 27421-27480 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 81.14 ms
# 🪟 Rows 27481-27540 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 84.54 ms
# 🪟 Rows 27541-27600 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 119.74 ms
# 🪟 Rows 27601-27660 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 100.96 ms
# 🪟 Rows 27661-27720 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 84.22 ms
# 🪟 Rows 27721-27780 → Predicted: Running (2) | Actual: Running (2) ✅ | Latency: 118.55 ms
# 🪟 Rows 27781-27840 → Predicted: Stair Down (5) | Actual: Running (2) ❌ | Latency: 123.74 ms
# 🪟 Rows 27841-27900 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 119.76 ms
# 🪟 Rows 27901-27960 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 79.04 ms
# 🪟 Rows 27961-28020 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 73.71 ms
# 🪟 Rows 28021-28080 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 79.56 ms
# 🪟 Rows 28081-28140 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 84.75 ms
# 🪟 Rows 28141-28200 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 80.97 ms
# 🪟 Rows 28201-28260 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 83.32 ms
# 🪟 Rows 28261-28320 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 84.29 ms
# 🪟 Rows 28321-28380 → Skipped (Label 0)
# 🪟 Rows 28381-28440 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 82.11 ms
# 🪟 Rows 28441-28500 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 83.4 ms
# 🪟 Rows 28501-28560 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 76.78 ms
# 🪟 Rows 28561-28620 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 95.23 ms
# 🪟 Rows 28621-28680 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 80.97 ms
# 🪟 Rows 28681-28740 → Predicted: Walking (1) | Actual: Stair Up (6) ❌ | Latency: 75.73 ms
# 🪟 Rows 28741-28800 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 77.43 ms
# 🪟 Rows 28801-28860 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 79.5 ms
# 🪟 Rows 28861-28920 → Predicted: Stair Down (5) | Actual: Stair Up (6) ❌ | Latency: 80.68 ms
# 🪟 Rows 28921-28980 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 78.07 ms
# 🪟 Rows 28981-29040 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 126.72 ms
# 🪟 Rows 29041-29100 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 79.84 ms
# 🪟 Rows 29101-29160 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 82.69 ms
# 🪟 Rows 29161-29220 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 121.44 ms
# 🪟 Rows 29221-29280 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 116.82 ms
# 🪟 Rows 29281-29340 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 78.05 ms
# 🪟 Rows 29341-29400 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 82.62 ms
# 🪟 Rows 29401-29460 → Predicted: Stair Down (5) | Actual: Stair Down (5) ✅ | Latency: 77.2 ms
# 🪟 Rows 29461-29520 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 73.12 ms
# 🪟 Rows 29521-29580 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 75.75 ms
# 🪟 Rows 29581-29640 → Predicted: Stair Down (5) | Actual: Stair Up (6) ❌ | Latency: 89.83 ms
# 🪟 Rows 29641-29700 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 83.03 ms
# 🪟 Rows 29701-29760 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 82.92 ms
# 🪟 Rows 29761-29820 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 134.11 ms
# 🪟 Rows 29821-29880 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 120.76 ms
# 🪟 Rows 29881-29940 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 127.57 ms
# 🪟 Rows 29941-30000 → Predicted: Stair Up (6) | Actual: Stair Up (6) ✅ | Latency: 84.48 ms
# 🪟 Rows 30001-30060 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.71 ms
# 🪟 Rows 30061-30120 → Predicted: Walking (1) | Actual: Walking (1) ✅ | Latency: 77.52 ms
# 🪟 Rows 30121-30180 → Skipped (Label 0)
# 🪟 Rows 30181-30240 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 75.18 ms
# 🪟 Rows 30241-30300 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 79.21 ms
# 🪟 Rows 30301-30360 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 75.47 ms
# 🪟 Rows 30361-30420 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 93.18 ms
# 🪟 Rows 30421-30480 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 85.07 ms
# 🪟 Rows 30481-30540 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 81.93 ms
# 🪟 Rows 30541-30600 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 84.73 ms
# 🪟 Rows 30601-30660 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 119.48 ms
# 🪟 Rows 30661-30720 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 97.29 ms
# 🪟 Rows 30721-30780 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 78.13 ms
# 🪟 Rows 30781-30840 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 76.88 ms
# 🪟 Rows 30841-30900 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 79.27 ms
# 🪟 Rows 30901-30960 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 80.1 ms
# 🪟 Rows 30961-31020 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 76.67 ms
# 🪟 Rows 31021-31080 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 78.05 ms
# 🪟 Rows 31081-31140 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 125.67 ms
# 🪟 Rows 31141-31200 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 86.9 ms
# 🪟 Rows 31201-31260 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 82.13 ms
# 🪟 Rows 31261-31320 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 118.64 ms
# 🪟 Rows 31321-31380 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 97.48 ms
# 🪟 Rows 31381-31440 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 78.98 ms
# 🪟 Rows 31441-31500 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 80.71 ms
# 🪟 Rows 31501-31560 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 82.32 ms
# 🪟 Rows 31561-31620 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 75.32 ms
# 🪟 Rows 31621-31680 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 80.01 ms
# 🪟 Rows 31681-31740 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 116.3 ms
# 🪟 Rows 31741-31800 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 77.05 ms
# 🪟 Rows 31801-31860 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 92.77 ms
# 🪟 Rows 31861-31920 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 83.66 ms
# 🪟 Rows 31921-31980 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 89.44 ms
# 🪟 Rows 31981-32040 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 87.43 ms
# 🪟 Rows 32041-32100 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 94.65 ms
# 🪟 Rows 32101-32160 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 77.49 ms
# 🪟 Rows 32161-32220 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 83.65 ms
# 🪟 Rows 32221-32280 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 80.21 ms
# 🪟 Rows 32281-32340 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 75.27 ms
# 🪟 Rows 32341-32400 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 123.35 ms
# 🪟 Rows 32401-32460 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 77.41 ms
# 🪟 Rows 32461-32520 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 77.34 ms
# 🪟 Rows 32521-32580 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 88.95 ms
# 🪟 Rows 32581-32640 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 81.02 ms
# 🪟 Rows 32641-32700 → Predicted: Sitting (3) | Actual: Standing (4) ❌ | Latency: 124.99 ms
# 🪟 Rows 32701-32760 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 94.39 ms
# 🪟 Rows 32761-32820 → Predicted: Standing (4) | Actual: Standing (4) ✅ | Latency: 81.61 ms
# 🪟 Rows 32821-32880 → Skipped (Label 0)
# 🪟 Rows 32881-32940 → Skipped (Label 0)
# 🪟 Rows 32941-33000 → Skipped (Label 0)
# 🪟 Rows 33001-33060 → Skipped (Label 0)
# 🪟 Rows 33061-33120 → Skipped (Label 0)
# 🪟 Rows 33121-33180 → Skipped (Label 0)
# 🪟 Rows 33181-33240 → Skipped (Label 0)
# 🪟 Rows 33241-33300 → Skipped (Label 0)
# 🪟 Rows 33301-33360 → Skipped (Label 0)
# 🪟 Rows 33361-33420 → Skipped (Label 0)
# 🪟 Rows 33421-33480 → Skipped (Label 0)
# 🪟 Rows 33481-33540 → Skipped (Label 0)
# 🪟 Rows 33541-33600 → Skipped (Label 0)
# 🪟 Rows 33601-33660 → Skipped (Label 0)
# 🪟 Rows 33661-33720 → Skipped (Label 0)
# 🪟 Rows 33721-33780 → Skipped (Label 0)
# 🪟 Rows 33781-33840 → Skipped (Label 0)
# 🪟 Rows 33841-33900 → Skipped (Label 0)
# 🪟 Rows 33901-33960 → Skipped (Label 0)
# 🪟 Rows 33961-34020 → Skipped (Label 0)
# 🪟 Rows 34021-34080 → Skipped (Label 0)
# 🪟 Rows 34081-34140 → Skipped (Label 0)
# 🪟 Rows 34141-34200 → Skipped (Label 0)
# 🪟 Rows 34201-34260 → Skipped (Label 0)
# 🪟 Rows 34261-34320 → Skipped (Label 0)
# 🪟 Rows 34321-34380 → Skipped (Label 0)
# 🪟 Rows 34381-34440 → Skipped (Label 0)
# 🪟 Rows 34441-34500 → Skipped (Label 0)
# 🪟 Rows 34501-34560 → Skipped (Label 0)
# 🪟 Rows 34561-34620 → Skipped (Label 0)
# 🪟 Rows 34621-34680 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 87.58 ms
# 🪟 Rows 34681-34740 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 78.26 ms
# 🪟 Rows 34741-34800 → Predicted: Sitting (3) | Actual: Sitting (3) ✅ | Latency: 77.13 ms
#
# ⛔ Stopped by user.
